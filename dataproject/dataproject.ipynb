# %% [markdown]
# # The gender gap in unemployment

# %% [markdown]
# > **Note the following:**
# > 1. This is *not* meant to be an example of an actual **data analysis project**, just an example of how to structure such a project.
# > 1. Remember the general advice on structuring and commenting your code from [lecture 5](https://numeconcopenhagen.netlify.com/lectures/Workflow_and_debugging).
# > 1. Remember this [guide](https://www.markdownguide.org/basic-syntax/) on markdown and (a bit of) latex.
# > 1. Turn on automatic numbering by clicking on the small icon on top of the table of contents in the left sidebar.
# > 1. The `dataproject.py` file includes a function which can be used multiple times in this notebook.

# %% [markdown]
# Imports and set magics:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from matplotlib_venn import venn2

# autoreload modules when code is run
# %load_ext autoreload
# %autoreload 2

# user written modules
import dataproject

# %% [markdown]
# # Read and clean data

# %% [markdown]
# Import your data, either through an API or manually, and load it.

# %%
#importing data and removing first 2 rows, as they are empty
unemp = pd.read_excel('/Users/nadahadraoui/Library/CloudStorage/OneDrive-UniversityofCopenhagen/Introduction to programming/Project/projects-2022-team-hjn/dataproject/AULP01.xlsx',skiprows=3, na_filter=False)
industries = pd.read_excel('/Users/nadahadraoui/Library/CloudStorage/OneDrive-UniversityofCopenhagen/Introduction to programming/Project/projects-2022-team-hjn/dataproject/AKU220K.xlsx', na_filter=False)

# %%
#looking at the data
unemp
# Out:
#                                            Unnamed: 0        TOT I alt  \
# 0                                                      000 Hele landet
# 1                                                2007              3.6
# 2                                                2008              2.6
# 3                                                2009              4.8
# 4                                                2010              6.1
# 5                                                2011              5.9
# 6                                                2012                6
# 7                                                2013              5.8
# 8                                                2014                5
# 9                                                2015              4.5
# 10                                               2016              4.1
# 11                                               2017              4.2
# 12                                               2018              3.8
# 13                                               2019              3.7
# 14                                               2020              4.6
# 15
# 16  Årsopgørelser af ledigheden følger kalenderåre...
#
#                 Unnamed: 2           Unnamed: 3             Unnamed: 4  \
# 0   084 Region Hovedstaden  085 Region Sjælland  083 Region Syddanmark
# 1                        4                  3.5                    3.3
# 2                        3                  2.6                    2.4
# 3                      4.7                  4.7                    4.8
# 4                        6                  6.2                    6.2
# 5                        6                  6.2                    6.1
# 6                      6.2                  6.2                    6.3
# 7                        6                  5.8                    5.9
# 8                      5.3                    5                    4.9
# 9                      4.7                  4.6                    4.6
# 10                     4.3                  4.1                    4.2
# 11                     4.2                  4.2                    4.2
# 12                     3.9                  3.8                    3.7
# 13                     3.7                  3.5                    3.6
# 14                     4.8                  4.3                    4.5
# 15
# 16
#
#                 Unnamed: 5              Unnamed: 6           M Mænd  \
# 0   082 Region Midtjylland  081 Region Nordjylland  000 Hele landet
# 1                      2.9                     4.5              2.9
# 2                      2.1                     3.2              2.4
# 3                      4.5                     5.7              5.5
# 4                      5.6                     6.6              6.9
# 5                      5.3                     6.3              6.2
# 6                      5.3                     6.1              6.1
# 7                      5.1                     5.6              5.7
# 8                      4.3                     5.3              4.8
# 9                      3.9                       5              4.4
# 10                     3.6                     4.5              3.9
# 11                     3.7                     4.7                4
# 12                     3.5                     4.3              3.6
# 13                     3.4                     4.1              3.4
# 14                     4.2                       5              4.5
# 15
# 16
#
#                 Unnamed: 8           Unnamed: 9            Unnamed: 10  \
# 0   084 Region Hovedstaden  085 Region Sjælland  083 Region Syddanmark
# 1                      3.7                  2.7                    2.6
# 2                        3                  2.4                    2.1
# 3                      5.3                  5.4                    5.4
# 4                      6.7                  7.2                    7.1
# 5                      6.4                  6.4                    6.4
# 6                      6.3                  6.2                    6.4
# 7                      6.2                  5.8                    5.8
# 8                      5.3                  4.9                    4.7
# 9                      4.6                  4.4                    4.4
# 10                     4.1                  3.9                      4
# 11                     4.1                    4                    4.1
# 12                     3.7                  3.6                    3.6
# 13                     3.5                  3.3                    3.4
# 14                     4.8                  4.2                    4.4
# 15
# 16
#
#                Unnamed: 11             Unnamed: 12        K Kvinder  \
# 0   082 Region Midtjylland  081 Region Nordjylland  000 Hele landet
# 1                      2.2                     3.3              4.4
# 2                      1.8                     2.7              2.9
# 3                      5.1                     6.5              4.1
# 4                      6.3                     7.7              5.1
# 5                      5.3                     6.6              5.7
# 6                      5.1                     6.1                6
# 7                      4.9                     5.6              5.8
# 8                        4                     5.2              5.2
# 9                      3.5                     4.8              4.8
# 10                     3.2                     4.2              4.4
# 11                     3.4                     4.6              4.4
# 12                     3.2                     4.2              4.1
# 13                     3.1                     3.8              3.9
# 14                       4                     4.9              4.7
# 15
# 16
#
#                Unnamed: 14          Unnamed: 15            Unnamed: 16  \
# 0   084 Region Hovedstaden  085 Region Sjælland  083 Region Syddanmark
# 1                      4.4                  4.3                    4.2
# 2                      3.1                  2.8                    2.7
# 3                      4.1                  3.9                      4
# 4                      5.2                  5.1                    5.2
# 5                      5.7                  5.9                    5.7
# 6                        6                  6.2                    6.2
# 7                      5.8                  5.9                      6
# 8                      5.3                  5.1                    5.2
# 9                      4.8                  4.7                    4.7
# 10                     4.4                  4.3                    4.3
# 11                     4.4                  4.4                    4.3
# 12                     4.1                  4.1                    3.9
# 13                     3.9                  3.7                    3.8
# 14                     4.9                  4.3                    4.5
# 15
# 16
#
#                Unnamed: 17             Unnamed: 18
# 0   082 Region Midtjylland  081 Region Nordjylland
# 1                      3.7                     5.9
# 2                      2.4                     3.7
# 3                      3.8                     4.8
# 4                      4.8                     5.5
# 5                      5.3                     5.9
# 6                      5.6                       6
# 7                      5.3                     5.7
# 8                      4.7                     5.4
# 9                      4.3                     5.3
# 10                       4                     4.9
# 11                       4                     4.8
# 12                     3.8                     4.5
# 13                     3.7                     4.3
# 14                     4.5                     5.1
# 15
# 16

# %%
#Renaming columns
unemp = unemp.rename(columns={"Unnamed: 0": "Years","TOT I alt":"Entire country (All)","Unnamed: 2":"Capital region (All)","Unnamed: 3":"Zealand (All)","Unnamed: 4":"South Denmark (All)","Unnamed: 5":"Mid Jutland (All)","Unnamed: 6":"Northern Jutland (A)", "M Mænd":"Entire Country (M)", "Unnamed: 8":"Capital region (M)","Unnamed: 9":"Zealand (M)","Unnamed: 10":"South Denmark (M)","Unnamed: 11":"Mid Jutland (M)","Unnamed: 12":"Northern Jutland (M)","K Kvinder":"Entire country (W)","Unnamed: 14":"Capital region (W)","Unnamed: 15":"Zealand (W)","Unnamed: 16":"South Denmark (W)","Unnamed: 17":"Mid Jutland (W)","Unnamed: 18":"Northern Jutland (W)"})
unemp
# Out:
#                                                 Years Entire country (All)  \
# 0                                                          000 Hele landet
# 1                                                2007                  3.6
# 2                                                2008                  2.6
# 3                                                2009                  4.8
# 4                                                2010                  6.1
# 5                                                2011                  5.9
# 6                                                2012                    6
# 7                                                2013                  5.8
# 8                                                2014                    5
# 9                                                2015                  4.5
# 10                                               2016                  4.1
# 11                                               2017                  4.2
# 12                                               2018                  3.8
# 13                                               2019                  3.7
# 14                                               2020                  4.6
# 15
# 16  Årsopgørelser af ledigheden følger kalenderåre...
#
#       Capital region (All)        Zealand (All)    South Denmark (All)  \
# 0   084 Region Hovedstaden  085 Region Sjælland  083 Region Syddanmark
# 1                        4                  3.5                    3.3
# 2                        3                  2.6                    2.4
# 3                      4.7                  4.7                    4.8
# 4                        6                  6.2                    6.2
# 5                        6                  6.2                    6.1
# 6                      6.2                  6.2                    6.3
# 7                        6                  5.8                    5.9
# 8                      5.3                    5                    4.9
# 9                      4.7                  4.6                    4.6
# 10                     4.3                  4.1                    4.2
# 11                     4.2                  4.2                    4.2
# 12                     3.9                  3.8                    3.7
# 13                     3.7                  3.5                    3.6
# 14                     4.8                  4.3                    4.5
# 15
# 16
#
#          Mid Jutland (All)    Northern Jutland (A) Entire Country (M)  \
# 0   082 Region Midtjylland  081 Region Nordjylland    000 Hele landet
# 1                      2.9                     4.5                2.9
# 2                      2.1                     3.2                2.4
# 3                      4.5                     5.7                5.5
# 4                      5.6                     6.6                6.9
# 5                      5.3                     6.3                6.2
# 6                      5.3                     6.1                6.1
# 7                      5.1                     5.6                5.7
# 8                      4.3                     5.3                4.8
# 9                      3.9                       5                4.4
# 10                     3.6                     4.5                3.9
# 11                     3.7                     4.7                  4
# 12                     3.5                     4.3                3.6
# 13                     3.4                     4.1                3.4
# 14                     4.2                       5                4.5
# 15
# 16
#
#         Capital region (M)          Zealand (M)      South Denmark (M)  \
# 0   084 Region Hovedstaden  085 Region Sjælland  083 Region Syddanmark
# 1                      3.7                  2.7                    2.6
# 2                        3                  2.4                    2.1
# 3                      5.3                  5.4                    5.4
# 4                      6.7                  7.2                    7.1
# 5                      6.4                  6.4                    6.4
# 6                      6.3                  6.2                    6.4
# 7                      6.2                  5.8                    5.8
# 8                      5.3                  4.9                    4.7
# 9                      4.6                  4.4                    4.4
# 10                     4.1                  3.9                      4
# 11                     4.1                    4                    4.1
# 12                     3.7                  3.6                    3.6
# 13                     3.5                  3.3                    3.4
# 14                     4.8                  4.2                    4.4
# 15
# 16
#
#            Mid Jutland (M)    Northern Jutland (M) Entire country (W)  \
# 0   082 Region Midtjylland  081 Region Nordjylland    000 Hele landet
# 1                      2.2                     3.3                4.4
# 2                      1.8                     2.7                2.9
# 3                      5.1                     6.5                4.1
# 4                      6.3                     7.7                5.1
# 5                      5.3                     6.6                5.7
# 6                      5.1                     6.1                  6
# 7                      4.9                     5.6                5.8
# 8                        4                     5.2                5.2
# 9                      3.5                     4.8                4.8
# 10                     3.2                     4.2                4.4
# 11                     3.4                     4.6                4.4
# 12                     3.2                     4.2                4.1
# 13                     3.1                     3.8                3.9
# 14                       4                     4.9                4.7
# 15
# 16
#
#         Capital region (W)          Zealand (W)      South Denmark (W)  \
# 0   084 Region Hovedstaden  085 Region Sjælland  083 Region Syddanmark
# 1                      4.4                  4.3                    4.2
# 2                      3.1                  2.8                    2.7
# 3                      4.1                  3.9                      4
# 4                      5.2                  5.1                    5.2
# 5                      5.7                  5.9                    5.7
# 6                        6                  6.2                    6.2
# 7                      5.8                  5.9                      6
# 8                      5.3                  5.1                    5.2
# 9                      4.8                  4.7                    4.7
# 10                     4.4                  4.3                    4.3
# 11                     4.4                  4.4                    4.3
# 12                     4.1                  4.1                    3.9
# 13                     3.9                  3.7                    3.8
# 14                     4.9                  4.3                    4.5
# 15
# 16
#
#            Mid Jutland (W)    Northern Jutland (W)
# 0   082 Region Midtjylland  081 Region Nordjylland
# 1                      3.7                     5.9
# 2                      2.4                     3.7
# 3                      3.8                     4.8
# 4                      4.8                     5.5
# 5                      5.3                     5.9
# 6                      5.6                       6
# 7                      5.3                     5.7
# 8                      4.7                     5.4
# 9                      4.3                     5.3
# 10                       4                     4.9
# 11                       4                     4.8
# 12                     3.8                     4.5
# 13                     3.7                     4.3
# 14                     4.5                     5.1
# 15
# 16

# %%
#dropping row 0
unemp=unemp.drop(0).head(16)
unemp
# Out:
#                                                 Years Entire country (All)  \
# 1                                                2007                  3.6
# 2                                                2008                  2.6
# 3                                                2009                  4.8
# 4                                                2010                  6.1
# 5                                                2011                  5.9
# 6                                                2012                    6
# 7                                                2013                  5.8
# 8                                                2014                    5
# 9                                                2015                  4.5
# 10                                               2016                  4.1
# 11                                               2017                  4.2
# 12                                               2018                  3.8
# 13                                               2019                  3.7
# 14                                               2020                  4.6
# 15
# 16  Årsopgørelser af ledigheden følger kalenderåre...
#
#    Capital region (All) Zealand (All) South Denmark (All) Mid Jutland (All)  \
# 1                     4           3.5                 3.3               2.9
# 2                     3           2.6                 2.4               2.1
# 3                   4.7           4.7                 4.8               4.5
# 4                     6           6.2                 6.2               5.6
# 5                     6           6.2                 6.1               5.3
# 6                   6.2           6.2                 6.3               5.3
# 7                     6           5.8                 5.9               5.1
# 8                   5.3             5                 4.9               4.3
# 9                   4.7           4.6                 4.6               3.9
# 10                  4.3           4.1                 4.2               3.6
# 11                  4.2           4.2                 4.2               3.7
# 12                  3.9           3.8                 3.7               3.5
# 13                  3.7           3.5                 3.6               3.4
# 14                  4.8           4.3                 4.5               4.2
# 15
# 16
#
#    Northern Jutland (A) Entire Country (M) Capital region (M) Zealand (M)  \
# 1                   4.5                2.9                3.7         2.7
# 2                   3.2                2.4                  3         2.4
# 3                   5.7                5.5                5.3         5.4
# 4                   6.6                6.9                6.7         7.2
# 5                   6.3                6.2                6.4         6.4
# 6                   6.1                6.1                6.3         6.2
# 7                   5.6                5.7                6.2         5.8
# 8                   5.3                4.8                5.3         4.9
# 9                     5                4.4                4.6         4.4
# 10                  4.5                3.9                4.1         3.9
# 11                  4.7                  4                4.1           4
# 12                  4.3                3.6                3.7         3.6
# 13                  4.1                3.4                3.5         3.3
# 14                    5                4.5                4.8         4.2
# 15
# 16
#
#    South Denmark (M) Mid Jutland (M) Northern Jutland (M) Entire country (W)  \
# 1                2.6             2.2                  3.3                4.4
# 2                2.1             1.8                  2.7                2.9
# 3                5.4             5.1                  6.5                4.1
# 4                7.1             6.3                  7.7                5.1
# 5                6.4             5.3                  6.6                5.7
# 6                6.4             5.1                  6.1                  6
# 7                5.8             4.9                  5.6                5.8
# 8                4.7               4                  5.2                5.2
# 9                4.4             3.5                  4.8                4.8
# 10                 4             3.2                  4.2                4.4
# 11               4.1             3.4                  4.6                4.4
# 12               3.6             3.2                  4.2                4.1
# 13               3.4             3.1                  3.8                3.9
# 14               4.4               4                  4.9                4.7
# 15
# 16
#
#    Capital region (W) Zealand (W) South Denmark (W) Mid Jutland (W)  \
# 1                 4.4         4.3               4.2             3.7
# 2                 3.1         2.8               2.7             2.4
# 3                 4.1         3.9                 4             3.8
# 4                 5.2         5.1               5.2             4.8
# 5                 5.7         5.9               5.7             5.3
# 6                   6         6.2               6.2             5.6
# 7                 5.8         5.9                 6             5.3
# 8                 5.3         5.1               5.2             4.7
# 9                 4.8         4.7               4.7             4.3
# 10                4.4         4.3               4.3               4
# 11                4.4         4.4               4.3               4
# 12                4.1         4.1               3.9             3.8
# 13                3.9         3.7               3.8             3.7
# 14                4.9         4.3               4.5             4.5
# 15
# 16
#
#    Northern Jutland (W)
# 1                   5.9
# 2                   3.7
# 3                   4.8
# 4                   5.5
# 5                   5.9
# 6                     6
# 7                   5.7
# 8                   5.4
# 9                   5.3
# 10                  4.9
# 11                  4.8
# 12                  4.5
# 13                  4.3
# 14                  5.1
# 15
# 16

# %%
#Dropping last two rows
unemp.drop(unemp.tail(2).index,inplace=True)
unemp
# Out:
#    Years Entire country (All) Capital region (All) Zealand (All)  \
# 1   2007                  3.6                    4           3.5
# 2   2008                  2.6                    3           2.6
# 3   2009                  4.8                  4.7           4.7
# 4   2010                  6.1                    6           6.2
# 5   2011                  5.9                    6           6.2
# 6   2012                    6                  6.2           6.2
# 7   2013                  5.8                    6           5.8
# 8   2014                    5                  5.3             5
# 9   2015                  4.5                  4.7           4.6
# 10  2016                  4.1                  4.3           4.1
# 11  2017                  4.2                  4.2           4.2
# 12  2018                  3.8                  3.9           3.8
# 13  2019                  3.7                  3.7           3.5
# 14  2020                  4.6                  4.8           4.3
#
#    South Denmark (All) Mid Jutland (All) Northern Jutland (A)  \
# 1                  3.3               2.9                  4.5
# 2                  2.4               2.1                  3.2
# 3                  4.8               4.5                  5.7
# 4                  6.2               5.6                  6.6
# 5                  6.1               5.3                  6.3
# 6                  6.3               5.3                  6.1
# 7                  5.9               5.1                  5.6
# 8                  4.9               4.3                  5.3
# 9                  4.6               3.9                    5
# 10                 4.2               3.6                  4.5
# 11                 4.2               3.7                  4.7
# 12                 3.7               3.5                  4.3
# 13                 3.6               3.4                  4.1
# 14                 4.5               4.2                    5
#
#    Entire Country (M) Capital region (M) Zealand (M) South Denmark (M)  \
# 1                 2.9                3.7         2.7               2.6
# 2                 2.4                  3         2.4               2.1
# 3                 5.5                5.3         5.4               5.4
# 4                 6.9                6.7         7.2               7.1
# 5                 6.2                6.4         6.4               6.4
# 6                 6.1                6.3         6.2               6.4
# 7                 5.7                6.2         5.8               5.8
# 8                 4.8                5.3         4.9               4.7
# 9                 4.4                4.6         4.4               4.4
# 10                3.9                4.1         3.9                 4
# 11                  4                4.1           4               4.1
# 12                3.6                3.7         3.6               3.6
# 13                3.4                3.5         3.3               3.4
# 14                4.5                4.8         4.2               4.4
#
#    Mid Jutland (M) Northern Jutland (M) Entire country (W) Capital region (W)  \
# 1              2.2                  3.3                4.4                4.4
# 2              1.8                  2.7                2.9                3.1
# 3              5.1                  6.5                4.1                4.1
# 4              6.3                  7.7                5.1                5.2
# 5              5.3                  6.6                5.7                5.7
# 6              5.1                  6.1                  6                  6
# 7              4.9                  5.6                5.8                5.8
# 8                4                  5.2                5.2                5.3
# 9              3.5                  4.8                4.8                4.8
# 10             3.2                  4.2                4.4                4.4
# 11             3.4                  4.6                4.4                4.4
# 12             3.2                  4.2                4.1                4.1
# 13             3.1                  3.8                3.9                3.9
# 14               4                  4.9                4.7                4.9
#
#    Zealand (W) South Denmark (W) Mid Jutland (W) Northern Jutland (W)
# 1          4.3               4.2             3.7                  5.9
# 2          2.8               2.7             2.4                  3.7
# 3          3.9                 4             3.8                  4.8
# 4          5.1               5.2             4.8                  5.5
# 5          5.9               5.7             5.3                  5.9
# 6          6.2               6.2             5.6                    6
# 7          5.9                 6             5.3                  5.7
# 8          5.1               5.2             4.7                  5.4
# 9          4.7               4.7             4.3                  5.3
# 10         4.3               4.3               4                  4.9
# 11         4.4               4.3               4                  4.8
# 12         4.1               3.9             3.8                  4.5
# 13         3.7               3.8             3.7                  4.3
# 14         4.3               4.5             4.5                  5.1

# %%
#reseting indices
unemp=unemp.reset_index(level=None, drop=True, inplace=False, col_level=0, col_fill='')
unemp
# Out:
#    Years Entire country (All) Capital region (All) Zealand (All)  \
# 0   2007                  3.6                    4           3.5
# 1   2008                  2.6                    3           2.6
# 2   2009                  4.8                  4.7           4.7
# 3   2010                  6.1                    6           6.2
# 4   2011                  5.9                    6           6.2
# 5   2012                    6                  6.2           6.2
# 6   2013                  5.8                    6           5.8
# 7   2014                    5                  5.3             5
# 8   2015                  4.5                  4.7           4.6
# 9   2016                  4.1                  4.3           4.1
# 10  2017                  4.2                  4.2           4.2
# 11  2018                  3.8                  3.9           3.8
# 12  2019                  3.7                  3.7           3.5
# 13  2020                  4.6                  4.8           4.3
#
#    South Denmark (All) Mid Jutland (All) Northern Jutland (A)  \
# 0                  3.3               2.9                  4.5
# 1                  2.4               2.1                  3.2
# 2                  4.8               4.5                  5.7
# 3                  6.2               5.6                  6.6
# 4                  6.1               5.3                  6.3
# 5                  6.3               5.3                  6.1
# 6                  5.9               5.1                  5.6
# 7                  4.9               4.3                  5.3
# 8                  4.6               3.9                    5
# 9                  4.2               3.6                  4.5
# 10                 4.2               3.7                  4.7
# 11                 3.7               3.5                  4.3
# 12                 3.6               3.4                  4.1
# 13                 4.5               4.2                    5
#
#    Entire Country (M) Capital region (M) Zealand (M) South Denmark (M)  \
# 0                 2.9                3.7         2.7               2.6
# 1                 2.4                  3         2.4               2.1
# 2                 5.5                5.3         5.4               5.4
# 3                 6.9                6.7         7.2               7.1
# 4                 6.2                6.4         6.4               6.4
# 5                 6.1                6.3         6.2               6.4
# 6                 5.7                6.2         5.8               5.8
# 7                 4.8                5.3         4.9               4.7
# 8                 4.4                4.6         4.4               4.4
# 9                 3.9                4.1         3.9                 4
# 10                  4                4.1           4               4.1
# 11                3.6                3.7         3.6               3.6
# 12                3.4                3.5         3.3               3.4
# 13                4.5                4.8         4.2               4.4
#
#    Mid Jutland (M) Northern Jutland (M) Entire country (W) Capital region (W)  \
# 0              2.2                  3.3                4.4                4.4
# 1              1.8                  2.7                2.9                3.1
# 2              5.1                  6.5                4.1                4.1
# 3              6.3                  7.7                5.1                5.2
# 4              5.3                  6.6                5.7                5.7
# 5              5.1                  6.1                  6                  6
# 6              4.9                  5.6                5.8                5.8
# 7                4                  5.2                5.2                5.3
# 8              3.5                  4.8                4.8                4.8
# 9              3.2                  4.2                4.4                4.4
# 10             3.4                  4.6                4.4                4.4
# 11             3.2                  4.2                4.1                4.1
# 12             3.1                  3.8                3.9                3.9
# 13               4                  4.9                4.7                4.9
#
#    Zealand (W) South Denmark (W) Mid Jutland (W) Northern Jutland (W)
# 0          4.3               4.2             3.7                  5.9
# 1          2.8               2.7             2.4                  3.7
# 2          3.9                 4             3.8                  4.8
# 3          5.1               5.2             4.8                  5.5
# 4          5.9               5.7             5.3                  5.9
# 5          6.2               6.2             5.6                    6
# 6          5.9                 6             5.3                  5.7
# 7          5.1               5.2             4.7                  5.4
# 8          4.7               4.7             4.3                  5.3
# 9          4.3               4.3               4                  4.9
# 10         4.4               4.3               4                  4.8
# 11         4.1               3.9             3.8                  4.5
# 12         3.7               3.8             3.7                  4.3
# 13         4.3               4.5             4.5                  5.1

# %%
####plotting unemployment (pct.) for women, men and in total

# %%
unemp[['Entire country (All)', 'Entire Country (M)', 'Entire country (W)']].plot(figsize=(12,6))
x = list(range(len(unemp["Years"])))
plt.ylabel('Unemployment in %')
plt.xlabel('Years 2007-2020')
plt.xticks(x, unemp["Years"])
plt.title('Unemployment in Denmark during 2007-2020')
plt.show()

# %% [markdown]
# We see that unemployment is generally higher for women than men during the period 2007-2008. An exception to this is during the financial crisis and the following years where unemployment for men was higher.

# %% [markdown]
# Looking at dataset for industries. We want to see if the difference in employment rates between women and men can be explained by them working in different industries.

# %%
industries
# Out:
#    Beskæftigede efter branche (DB07 10-grp.), tid, køn og område Unnamed: 1  \
# 0                               Enhed: 1.000 personer
# 1
# 2
# 3                                   TOT Erhverv i alt                2008K1
# 4                                                                    2020K1
# 5                     1 Landbrug, skovbrug og fiskeri                2008K1
# 6                                                                    2020K1
# 7   2 Industri, råstofindvinding og forsyningsvirk...                2008K1
# 8                                                                    2020K1
# 9                                    3 Bygge og anlæg                2008K1
# 10                                                                   2020K1
# 11                          4 Handel og transport mv.                2008K1
# 12                                                                   2020K1
# 13                     5 Information og kommunikation                2008K1
# 14                                                                   2020K1
# 15                       6 Finansiering og forsikring                2008K1
# 16                                                                   2020K1
# 17                      7 Ejendomshandel og udlejning                2008K1
# 18                                                                   2020K1
# 19                                  8 Erhvervsservice                2008K1
# 20                                                                   2020K1
# 21  9 Offentlig administration, undervisning og su...                2008K1
# 22                                                                   2020K1
# 23                 10 Kultur, fritid og anden service                2008K1
# 24                                                                   2020K1
#
#      Unnamed: 2          Unnamed: 3       Unnamed: 4         Unnamed: 5  \
# 0
# 1         I alt
# 2   Hele landet  Region Hovedstaden  Region Sjælland  Region Syddanmark
# 3          2726                 857              393                576
# 4          2767                 936              366                555
# 5            63                  ..                7                 23
# 6            52                  ..                6                 14
# 7           430                  85               51                118
# 8           342                  77               41                 86
# 9           196                  47               38                 46
# 10          163                  39               30                 40
# 11          629                 188               95                136
# 12          651                 211               88                141
# 13          109                  58               14                 11
# 14          116                  69                9                 11
# 15           84                  40               13                 10
# 16           81                  42               11                 11
# 17           30                  12                4                  5
# 18           39                  15                6                  6
# 19          205                  91               28                 32
# 20          286                 126               33                 46
# 21          857                 277              128                175
# 22          896                 298              127                175
# 23          123                  54               14                 20
# 24          133                  56               15                 24
#
#             Unnamed: 6          Unnamed: 7   Unnamed: 8          Unnamed: 9  \
# 0
# 1                                                  Mænd
# 2   Region Midtjylland  Region Nordjylland  Hele landet  Region Hovedstaden
# 3                  626                 275         1444                 438
# 4                  638                 272         1453                 479
# 5                   19                  11           46                  ..
# 6                   20                  11           40                  ..
# 7                  122                  53          300                  52
# 8                   98                  40          242                  43
# 9                   45                  20          178                  43
# 10                  35                  18          149                  35
# 11                 151                  60          373                 106
# 12                 152                  59          386                 125
# 13                  19                   7           74                  38
# 14                  21                   7           87                  52
# 15                  14                   6           42                  21
# 16                  13                   4           44                  23
# 17                   5                  ..           20                   8
# 18                   7                   5           24                   9
# 19                  40                  15          107                  49
# 20                  59                  22          159                  67
# 21                 187                  89          255                  94
# 22                 203                  94          260                 101
# 23                  24                  10           49                  24
# 24                  28                  11           58                  22
#
#         Unnamed: 10        Unnamed: 11         Unnamed: 12  \
# 0
# 1
# 2   Region Sjælland  Region Syddanmark  Region Midtjylland
# 3               208                310                 336
# 4               185                292                 349
# 5                 5                 17                  14
# 6                 4                  9                  16
# 7                37                 83                  89
# 8                28                 64                  73
# 9                33                 41                  42
# 10               27                 37                  33
# 11               57                 82                  91
# 12               56                 84                  88
# 13               11                  7                  13
# 14                7                  7                  16
# 15                6                  5                   7
# 16                6                  6                   7
# 17               ..                  4                   4
# 18               ..                  4                   5
# 19               15                 17                  19
# 20               18                 25                  35
# 21               37                 48                  46
# 22               30                 44                  61
# 23                4                  7                  10
# 24                7                 10                  14
#
#            Unnamed: 13  Unnamed: 14         Unnamed: 15      Unnamed: 16  \
# 0
# 1                           Kvinder
# 2   Region Nordjylland  Hele landet  Region Hovedstaden  Region Sjælland
# 3                  152         1282                 419              185
# 4                  148         1314                 457              180
# 5                    7           17                  ..               ..
# 6                    9           12                  ..               ..
# 7                   39          130                  34               13
# 8                   33          100                  34               13
# 9                   19           18                   5                5
# 10                  17           14                   4                4
# 11                  37          257                  82               38
# 12                  33          265                  86               32
# 13                   5           35                  19                4
# 14                   5           29                  16               ..
# 15                  ..           41                  19                8
# 16                  ..           37                  19                5
# 17                  ..           10                   4               ..
# 18                   4           14                   6               ..
# 19                   7           98                  42               13
# 20                  13          127                  59               15
# 21                  28          602                 183               91
# 22                  24          636                 197               97
# 23                   4           73                  31               10
# 24                   5           75                  34                8
#
#           Unnamed: 17         Unnamed: 18         Unnamed: 19
# 0
# 1
# 2   Region Syddanmark  Region Midtjylland  Region Nordjylland
# 3                 266                 290                 123
# 4                 263                 290                 125
# 5                   6                   5                  ..
# 6                   5                   4                  ..
# 7                  36                  33                  14
# 8                  21                  25                   8
# 9                   5                  ..                  ..
# 10                  4                  ..                  ..
# 11                 54                  59                  23
# 12                 57                  64                  26
# 13                  4                   6                  ..
# 14                  4                   5                  ..
# 15                  5                   7                  ..
# 16                  5                   6                  ..
# 17                 ..                  ..                  ..
# 18                 ..                  ..                  ..
# 19                 15                  21                   8
# 20                 21                  24                   9
# 21                127                 141                  60
# 22                130                 142                  70
# 23                 12                  14                   7
# 24                 14                  14                   5

# %%
#renaming columns
industries = industries.rename(columns={"Beskæftigede efter branche (DB07 10-grp.), tid, køn og område": "Industries","Unnamed: 1":"Years","Unnamed: 2":"Entire country (All)","Unnamed: 3":"Capital region (All)","Unnamed: 4":"Zealand (All)","Unnamed: 5":"South Denmark (All)","Unnamed: 6":"Mid Jutland (All)", "Unnamed: 7":"Northern Jutland (M)", "Unnamed: 8":"Entire country (M)","Unnamed: 9":"Capital region (M)","Unnamed: 10":"Zealand (M)","Unnamed: 11":"South Denmark (M)","Unnamed: 12":"Mid Jutland (M)","Unnamed: 13":"Northern Jutland (M)","Unnamed: 14":"Entire country (W)","Unnamed: 15":"Capital region (W)","Unnamed: 16":"Zealand (W)","Unnamed: 17":"South Denmark (W)","Unnamed: 18":"Mid Jutland (W)", "Unnamed: 19":"Northern Jutland (W)", })
industries
# Out:
#                                            Industries   Years  \
# 0                               Enhed: 1.000 personer
# 1
# 2
# 3                                   TOT Erhverv i alt  2008K1
# 4                                                      2020K1
# 5                     1 Landbrug, skovbrug og fiskeri  2008K1
# 6                                                      2020K1
# 7   2 Industri, råstofindvinding og forsyningsvirk...  2008K1
# 8                                                      2020K1
# 9                                    3 Bygge og anlæg  2008K1
# 10                                                     2020K1
# 11                          4 Handel og transport mv.  2008K1
# 12                                                     2020K1
# 13                     5 Information og kommunikation  2008K1
# 14                                                     2020K1
# 15                       6 Finansiering og forsikring  2008K1
# 16                                                     2020K1
# 17                      7 Ejendomshandel og udlejning  2008K1
# 18                                                     2020K1
# 19                                  8 Erhvervsservice  2008K1
# 20                                                     2020K1
# 21  9 Offentlig administration, undervisning og su...  2008K1
# 22                                                     2020K1
# 23                 10 Kultur, fritid og anden service  2008K1
# 24                                                     2020K1
#
#    Entire country (All) Capital region (All)    Zealand (All)  \
# 0
# 1                 I alt
# 2           Hele landet   Region Hovedstaden  Region Sjælland
# 3                  2726                  857              393
# 4                  2767                  936              366
# 5                    63                   ..                7
# 6                    52                   ..                6
# 7                   430                   85               51
# 8                   342                   77               41
# 9                   196                   47               38
# 10                  163                   39               30
# 11                  629                  188               95
# 12                  651                  211               88
# 13                  109                   58               14
# 14                  116                   69                9
# 15                   84                   40               13
# 16                   81                   42               11
# 17                   30                   12                4
# 18                   39                   15                6
# 19                  205                   91               28
# 20                  286                  126               33
# 21                  857                  277              128
# 22                  896                  298              127
# 23                  123                   54               14
# 24                  133                   56               15
#
#    South Denmark (All)   Mid Jutland (All) Northern Jutland (M)  \
# 0
# 1
# 2    Region Syddanmark  Region Midtjylland   Region Nordjylland
# 3                  576                 626                  275
# 4                  555                 638                  272
# 5                   23                  19                   11
# 6                   14                  20                   11
# 7                  118                 122                   53
# 8                   86                  98                   40
# 9                   46                  45                   20
# 10                  40                  35                   18
# 11                 136                 151                   60
# 12                 141                 152                   59
# 13                  11                  19                    7
# 14                  11                  21                    7
# 15                  10                  14                    6
# 16                  11                  13                    4
# 17                   5                   5                   ..
# 18                   6                   7                    5
# 19                  32                  40                   15
# 20                  46                  59                   22
# 21                 175                 187                   89
# 22                 175                 203                   94
# 23                  20                  24                   10
# 24                  24                  28                   11
#
#    Entire country (M)  Capital region (M)      Zealand (M)  South Denmark (M)  \
# 0
# 1                Mænd
# 2         Hele landet  Region Hovedstaden  Region Sjælland  Region Syddanmark
# 3                1444                 438              208                310
# 4                1453                 479              185                292
# 5                  46                  ..                5                 17
# 6                  40                  ..                4                  9
# 7                 300                  52               37                 83
# 8                 242                  43               28                 64
# 9                 178                  43               33                 41
# 10                149                  35               27                 37
# 11                373                 106               57                 82
# 12                386                 125               56                 84
# 13                 74                  38               11                  7
# 14                 87                  52                7                  7
# 15                 42                  21                6                  5
# 16                 44                  23                6                  6
# 17                 20                   8               ..                  4
# 18                 24                   9               ..                  4
# 19                107                  49               15                 17
# 20                159                  67               18                 25
# 21                255                  94               37                 48
# 22                260                 101               30                 44
# 23                 49                  24                4                  7
# 24                 58                  22                7                 10
#
#    Northern Jutland (M)         Unnamed: 13 Entire country (W)  \
# 0
# 1                                                      Kvinder
# 2    Region Midtjylland  Region Nordjylland        Hele landet
# 3                   336                 152               1282
# 4                   349                 148               1314
# 5                    14                   7                 17
# 6                    16                   9                 12
# 7                    89                  39                130
# 8                    73                  33                100
# 9                    42                  19                 18
# 10                   33                  17                 14
# 11                   91                  37                257
# 12                   88                  33                265
# 13                   13                   5                 35
# 14                   16                   5                 29
# 15                    7                  ..                 41
# 16                    7                  ..                 37
# 17                    4                  ..                 10
# 18                    5                   4                 14
# 19                   19                   7                 98
# 20                   35                  13                127
# 21                   46                  28                602
# 22                   61                  24                636
# 23                   10                   4                 73
# 24                   14                   5                 75
#
#     Capital region (W)      Zealand (W)  South Denmark (W)  \
# 0
# 1
# 2   Region Hovedstaden  Region Sjælland  Region Syddanmark
# 3                  419              185                266
# 4                  457              180                263
# 5                   ..               ..                  6
# 6                   ..               ..                  5
# 7                   34               13                 36
# 8                   34               13                 21
# 9                    5                5                  5
# 10                   4                4                  4
# 11                  82               38                 54
# 12                  86               32                 57
# 13                  19                4                  4
# 14                  16               ..                  4
# 15                  19                8                  5
# 16                  19                5                  5
# 17                   4               ..                 ..
# 18                   6               ..                 ..
# 19                  42               13                 15
# 20                  59               15                 21
# 21                 183               91                127
# 22                 197               97                130
# 23                  31               10                 12
# 24                  34                8                 14
#
#    Northern Jutland (W)         Unnamed: 19
# 0
# 1
# 2    Region Midtjylland  Region Nordjylland
# 3                   290                 123
# 4                   290                 125
# 5                     5                  ..
# 6                     4                  ..
# 7                    33                  14
# 8                    25                   8
# 9                    ..                  ..
# 10                   ..                  ..
# 11                   59                  23
# 12                   64                  26
# 13                    6                  ..
# 14                    5                  ..
# 15                    7                  ..
# 16                    6                  ..
# 17                   ..                  ..
# 18                   ..                  ..
# 19                   21                   8
# 20                   24                   9
# 21                  141                  60
# 22                  142                  70
# 23                   14                   7
# 24                   14                   5

# %%
##dropping row 0, 1 and 2
industries=industries.drop([0,1,2]).head(24)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/r2/1xrlyn0x2239x5svpgbg13_m0000gn/T/ipykernel_51037/2525849272.py in <module>
#       1 ##dropping row 0, 1 and 2
# ----> 2 industries=industries.drop([0,1,2]).head(24)
#       3 industries
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4946                 weight  1.0     0.8
#    4947         """
# -> 4948         return super().drop(
#    4949             labels=labels,
#    4950             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4277         for axis, labels in axes.items():
#    4278             if labels is not None:
# -> 4279                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4280
#    4281         if inplace:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4321                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4322             else:
# -> 4323                 new_axis = axis.drop(labels, errors=errors)
#    4324             indexer = axis.get_indexer(new_axis)
#    4325
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6642         if mask.any():
#    6643             if errors != "ignore":
# -> 6644                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645             indexer = indexer[~mask]
#    6646         return self.delete(indexer)
#
# KeyError: '[0, 1, 2] not found in axis'

# %%
industries
# Out:
#                                            Industries   Years  \
# 3                                   TOT Erhverv i alt  2008K1
# 4                                                      2020K1
# 5                     1 Landbrug, skovbrug og fiskeri  2008K1
# 6                                                      2020K1
# 7   2 Industri, råstofindvinding og forsyningsvirk...  2008K1
# 8                                                      2020K1
# 9                                    3 Bygge og anlæg  2008K1
# 10                                                     2020K1
# 11                          4 Handel og transport mv.  2008K1
# 12                                                     2020K1
# 13                     5 Information og kommunikation  2008K1
# 14                                                     2020K1
# 15                       6 Finansiering og forsikring  2008K1
# 16                                                     2020K1
# 17                      7 Ejendomshandel og udlejning  2008K1
# 18                                                     2020K1
# 19                                  8 Erhvervsservice  2008K1
# 20                                                     2020K1
# 21  9 Offentlig administration, undervisning og su...  2008K1
# 22                                                     2020K1
# 23                 10 Kultur, fritid og anden service  2008K1
# 24                                                     2020K1
#
#    Entire country (All) Capital region (All) Zealand (All)  \
# 3                  2726                  857           393
# 4                  2767                  936           366
# 5                    63                   ..             7
# 6                    52                   ..             6
# 7                   430                   85            51
# 8                   342                   77            41
# 9                   196                   47            38
# 10                  163                   39            30
# 11                  629                  188            95
# 12                  651                  211            88
# 13                  109                   58            14
# 14                  116                   69             9
# 15                   84                   40            13
# 16                   81                   42            11
# 17                   30                   12             4
# 18                   39                   15             6
# 19                  205                   91            28
# 20                  286                  126            33
# 21                  857                  277           128
# 22                  896                  298           127
# 23                  123                   54            14
# 24                  133                   56            15
#
#    South Denmark (All) Mid Jutland (All) Northern Jutland (M)  \
# 3                  576               626                  275
# 4                  555               638                  272
# 5                   23                19                   11
# 6                   14                20                   11
# 7                  118               122                   53
# 8                   86                98                   40
# 9                   46                45                   20
# 10                  40                35                   18
# 11                 136               151                   60
# 12                 141               152                   59
# 13                  11                19                    7
# 14                  11                21                    7
# 15                  10                14                    6
# 16                  11                13                    4
# 17                   5                 5                   ..
# 18                   6                 7                    5
# 19                  32                40                   15
# 20                  46                59                   22
# 21                 175               187                   89
# 22                 175               203                   94
# 23                  20                24                   10
# 24                  24                28                   11
#
#    Entire country (M) Capital region (M) Zealand (M) South Denmark (M)  \
# 3                1444                438         208               310
# 4                1453                479         185               292
# 5                  46                 ..           5                17
# 6                  40                 ..           4                 9
# 7                 300                 52          37                83
# 8                 242                 43          28                64
# 9                 178                 43          33                41
# 10                149                 35          27                37
# 11                373                106          57                82
# 12                386                125          56                84
# 13                 74                 38          11                 7
# 14                 87                 52           7                 7
# 15                 42                 21           6                 5
# 16                 44                 23           6                 6
# 17                 20                  8          ..                 4
# 18                 24                  9          ..                 4
# 19                107                 49          15                17
# 20                159                 67          18                25
# 21                255                 94          37                48
# 22                260                101          30                44
# 23                 49                 24           4                 7
# 24                 58                 22           7                10
#
#    Northern Jutland (M) Unnamed: 13 Entire country (W) Capital region (W)  \
# 3                   336         152               1282                419
# 4                   349         148               1314                457
# 5                    14           7                 17                 ..
# 6                    16           9                 12                 ..
# 7                    89          39                130                 34
# 8                    73          33                100                 34
# 9                    42          19                 18                  5
# 10                   33          17                 14                  4
# 11                   91          37                257                 82
# 12                   88          33                265                 86
# 13                   13           5                 35                 19
# 14                   16           5                 29                 16
# 15                    7          ..                 41                 19
# 16                    7          ..                 37                 19
# 17                    4          ..                 10                  4
# 18                    5           4                 14                  6
# 19                   19           7                 98                 42
# 20                   35          13                127                 59
# 21                   46          28                602                183
# 22                   61          24                636                197
# 23                   10           4                 73                 31
# 24                   14           5                 75                 34
#
#    Zealand (W) South Denmark (W) Northern Jutland (W) Unnamed: 19
# 3          185               266                  290         123
# 4          180               263                  290         125
# 5           ..                 6                    5          ..
# 6           ..                 5                    4          ..
# 7           13                36                   33          14
# 8           13                21                   25           8
# 9            5                 5                   ..          ..
# 10           4                 4                   ..          ..
# 11          38                54                   59          23
# 12          32                57                   64          26
# 13           4                 4                    6          ..
# 14          ..                 4                    5          ..
# 15           8                 5                    7          ..
# 16           5                 5                    6          ..
# 17          ..                ..                   ..          ..
# 18          ..                ..                   ..          ..
# 19          13                15                   21           8
# 20          15                21                   24           9
# 21          91               127                  141          60
# 22          97               130                  142          70
# 23          10                12                   14           7
# 24           8                14                   14           5

# %%
#reseting indices
industries=industries.reset_index(level=None, drop=True, inplace=False, col_level=0, col_fill='')

# %%
industries
# Out:
#                                            Industries   Years  \
# 0                                   TOT Erhverv i alt  2008K1
# 1                                                      2020K1
# 2                     1 Landbrug, skovbrug og fiskeri  2008K1
# 3                                                      2020K1
# 4   2 Industri, råstofindvinding og forsyningsvirk...  2008K1
# 5                                                      2020K1
# 6                                    3 Bygge og anlæg  2008K1
# 7                                                      2020K1
# 8                           4 Handel og transport mv.  2008K1
# 9                                                      2020K1
# 10                     5 Information og kommunikation  2008K1
# 11                                                     2020K1
# 12                       6 Finansiering og forsikring  2008K1
# 13                                                     2020K1
# 14                      7 Ejendomshandel og udlejning  2008K1
# 15                                                     2020K1
# 16                                  8 Erhvervsservice  2008K1
# 17                                                     2020K1
# 18  9 Offentlig administration, undervisning og su...  2008K1
# 19                                                     2020K1
# 20                 10 Kultur, fritid og anden service  2008K1
# 21                                                     2020K1
#
#    Entire country (All) Capital region (All) Zealand (All)  \
# 0                  2726                  857           393
# 1                  2767                  936           366
# 2                    63                   ..             7
# 3                    52                   ..             6
# 4                   430                   85            51
# 5                   342                   77            41
# 6                   196                   47            38
# 7                   163                   39            30
# 8                   629                  188            95
# 9                   651                  211            88
# 10                  109                   58            14
# 11                  116                   69             9
# 12                   84                   40            13
# 13                   81                   42            11
# 14                   30                   12             4
# 15                   39                   15             6
# 16                  205                   91            28
# 17                  286                  126            33
# 18                  857                  277           128
# 19                  896                  298           127
# 20                  123                   54            14
# 21                  133                   56            15
#
#    South Denmark (All) Mid Jutland (All) Northern Jutland (M)  \
# 0                  576               626                  275
# 1                  555               638                  272
# 2                   23                19                   11
# 3                   14                20                   11
# 4                  118               122                   53
# 5                   86                98                   40
# 6                   46                45                   20
# 7                   40                35                   18
# 8                  136               151                   60
# 9                  141               152                   59
# 10                  11                19                    7
# 11                  11                21                    7
# 12                  10                14                    6
# 13                  11                13                    4
# 14                   5                 5                   ..
# 15                   6                 7                    5
# 16                  32                40                   15
# 17                  46                59                   22
# 18                 175               187                   89
# 19                 175               203                   94
# 20                  20                24                   10
# 21                  24                28                   11
#
#    Entire country (M) Capital region (M) Zealand (M) South Denmark (M)  \
# 0                1444                438         208               310
# 1                1453                479         185               292
# 2                  46                 ..           5                17
# 3                  40                 ..           4                 9
# 4                 300                 52          37                83
# 5                 242                 43          28                64
# 6                 178                 43          33                41
# 7                 149                 35          27                37
# 8                 373                106          57                82
# 9                 386                125          56                84
# 10                 74                 38          11                 7
# 11                 87                 52           7                 7
# 12                 42                 21           6                 5
# 13                 44                 23           6                 6
# 14                 20                  8          ..                 4
# 15                 24                  9          ..                 4
# 16                107                 49          15                17
# 17                159                 67          18                25
# 18                255                 94          37                48
# 19                260                101          30                44
# 20                 49                 24           4                 7
# 21                 58                 22           7                10
#
#    Northern Jutland (M) Unnamed: 13 Entire country (W) Capital region (W)  \
# 0                   336         152               1282                419
# 1                   349         148               1314                457
# 2                    14           7                 17                 ..
# 3                    16           9                 12                 ..
# 4                    89          39                130                 34
# 5                    73          33                100                 34
# 6                    42          19                 18                  5
# 7                    33          17                 14                  4
# 8                    91          37                257                 82
# 9                    88          33                265                 86
# 10                   13           5                 35                 19
# 11                   16           5                 29                 16
# 12                    7          ..                 41                 19
# 13                    7          ..                 37                 19
# 14                    4          ..                 10                  4
# 15                    5           4                 14                  6
# 16                   19           7                 98                 42
# 17                   35          13                127                 59
# 18                   46          28                602                183
# 19                   61          24                636                197
# 20                   10           4                 73                 31
# 21                   14           5                 75                 34
#
#    Zealand (W) South Denmark (W) Northern Jutland (W) Unnamed: 19
# 0          185               266                  290         123
# 1          180               263                  290         125
# 2           ..                 6                    5          ..
# 3           ..                 5                    4          ..
# 4           13                36                   33          14
# 5           13                21                   25           8
# 6            5                 5                   ..          ..
# 7            4                 4                   ..          ..
# 8           38                54                   59          23
# 9           32                57                   64          26
# 10           4                 4                    6          ..
# 11          ..                 4                    5          ..
# 12           8                 5                    7          ..
# 13           5                 5                    6          ..
# 14          ..                ..                   ..          ..
# 15          ..                ..                   ..          ..
# 16          13                15                   21           8
# 17          15                21                   24           9
# 18          91               127                  141          60
# 19          97               130                  142          70
# 20          10                12                   14           7
# 21           8                14                   14           5

# %%
data.columns= ["industries]
plt.title("Indian Unemployment")
sns.histplot(x="Estimated Employed", hue="Region", data=data)
plt.show()

# %% [markdown]
# ## Explore each data set

# %% [markdown]
# In order to be able to **explore the raw data**, you may provide **static** and **interactive plots** to show important developments

# %% [markdown]
# **Interactive plot** :

# %%
def plot_func():
    # Function that operates on data set
    pass

widgets.interact(plot_func, 
    # Let the widget interact with data through plot_func()    
);
# Out:
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %% [markdown]
# Explain what you see when moving elements of the interactive plot around.

# %% [markdown]
# # Merge data sets

# %% [markdown]
# Now you create combinations of your loaded data sets. Remember the illustration of a (inner) **merge**:

# %%
plt.figure(figsize=(15,7))
v = venn2(subsets = (4, 4, 10), set_labels = ('Data X', 'Data Y'))
v.get_label_by_id('100').set_text('dropped')
v.get_label_by_id('010').set_text('dropped' )
v.get_label_by_id('110').set_text('included')
plt.show()

# %% [markdown]
# Here we are dropping elements from both data set X and data set Y. A left join would keep all observations in data X intact and subset only from Y.
#
# Make sure that your resulting data sets have the correct number of rows and columns. That is, be clear about which observations are thrown away.
#
# **Note:** Don't make Venn diagrams in your own data project. It is just for exposition.

# %% [markdown]
# # Analysis

# %% [markdown]
# To get a quick overview of the data, we show some **summary statistics** on a meaningful aggregation.

# %% [markdown]
# MAKE FURTHER ANALYSIS. EXPLAIN THE CODE BRIEFLY AND SUMMARIZE THE RESULTS.

# %% [markdown]
# # Conclusion

# %% [markdown]
# ADD CONCISE CONLUSION.
