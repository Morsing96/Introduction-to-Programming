# %% [markdown]
# # The gender gap in unemployment

# %% [markdown]
# > **Note the following:**
# > 1. This is *not* meant to be an example of an actual **data analysis project**, just an example of how to structure such a project.
# > 1. Remember the general advice on structuring and commenting your code from [lecture 5](https://numeconcopenhagen.netlify.com/lectures/Workflow_and_debugging).
# > 1. Remember this [guide](https://www.markdownguide.org/basic-syntax/) on markdown and (a bit of) latex.
# > 1. Turn on automatic numbering by clicking on the small icon on top of the table of contents in the left sidebar.
# > 1. The `dataproject.py` file includes a function which can be used multiple times in this notebook.

# %% [markdown]
# Imports and set magics:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from matplotlib_venn import venn2
from matplotlib.pyplot import figure

# autoreload modules when code is run
# %load_ext autoreload
# %autoreload 2

# user written modules
import dataproject

# %% [markdown]
# # Read and clean data

# %% [markdown]
# Import your data, either through an API or manually, and load it.

# %%
#importing data and removing first 2 rows, as they are empty
unemp = pd.read_excel('/Users/nadahadraoui/Library/CloudStorage/OneDrive-UniversityofCopenhagen/Introduction to programming/Project/projects-2022-team-hjn/dataproject/AULP01.xlsx',skiprows=3, na_filter=False)
industries = pd.read_excel('/Users/nadahadraoui/Library/CloudStorage/OneDrive-UniversityofCopenhagen/Introduction to programming/Project/projects-2022-team-hjn/dataproject/AKU220K.xlsx', na_filter=False)
industry = pd.read_excel('/Users/nadahadraoui/Library/CloudStorage/OneDrive-UniversityofCopenhagen/Introduction to programming/Project/projects-2022-team-hjn/dataproject/AKU220K2.xlsx', na_filter=False)
industry2 = pd.read_excel('/Users/nadahadraoui/Library/CloudStorage/OneDrive-UniversityofCopenhagen/Introduction to programming/Project/projects-2022-team-hjn/dataproject/AKU220K3.xlsx', na_filter=False)

# %%
#looking at the data
unemp
# Out:
#                                            Unnamed: 0        TOT I alt  \
# 0                                                      000 Hele landet
# 1                                                2007              3.6
# 2                                                2008              2.6
# 3                                                2009              4.8
# 4                                                2010              6.1
# 5                                                2011              5.9
# 6                                                2012                6
# 7                                                2013              5.8
# 8                                                2014                5
# 9                                                2015              4.5
# 10                                               2016              4.1
# 11                                               2017              4.2
# 12                                               2018              3.8
# 13                                               2019              3.7
# 14                                               2020              4.6
# 15
# 16  Årsopgørelser af ledigheden følger kalenderåre...
#
#                 Unnamed: 2           Unnamed: 3             Unnamed: 4  \
# 0   084 Region Hovedstaden  085 Region Sjælland  083 Region Syddanmark
# 1                        4                  3.5                    3.3
# 2                        3                  2.6                    2.4
# 3                      4.7                  4.7                    4.8
# 4                        6                  6.2                    6.2
# 5                        6                  6.2                    6.1
# 6                      6.2                  6.2                    6.3
# 7                        6                  5.8                    5.9
# 8                      5.3                    5                    4.9
# 9                      4.7                  4.6                    4.6
# 10                     4.3                  4.1                    4.2
# 11                     4.2                  4.2                    4.2
# 12                     3.9                  3.8                    3.7
# 13                     3.7                  3.5                    3.6
# 14                     4.8                  4.3                    4.5
# 15
# 16
#
#                 Unnamed: 5              Unnamed: 6           M Mænd  \
# 0   082 Region Midtjylland  081 Region Nordjylland  000 Hele landet
# 1                      2.9                     4.5              2.9
# 2                      2.1                     3.2              2.4
# 3                      4.5                     5.7              5.5
# 4                      5.6                     6.6              6.9
# 5                      5.3                     6.3              6.2
# 6                      5.3                     6.1              6.1
# 7                      5.1                     5.6              5.7
# 8                      4.3                     5.3              4.8
# 9                      3.9                       5              4.4
# 10                     3.6                     4.5              3.9
# 11                     3.7                     4.7                4
# 12                     3.5                     4.3              3.6
# 13                     3.4                     4.1              3.4
# 14                     4.2                       5              4.5
# 15
# 16
#
#                 Unnamed: 8           Unnamed: 9            Unnamed: 10  \
# 0   084 Region Hovedstaden  085 Region Sjælland  083 Region Syddanmark
# 1                      3.7                  2.7                    2.6
# 2                        3                  2.4                    2.1
# 3                      5.3                  5.4                    5.4
# 4                      6.7                  7.2                    7.1
# 5                      6.4                  6.4                    6.4
# 6                      6.3                  6.2                    6.4
# 7                      6.2                  5.8                    5.8
# 8                      5.3                  4.9                    4.7
# 9                      4.6                  4.4                    4.4
# 10                     4.1                  3.9                      4
# 11                     4.1                    4                    4.1
# 12                     3.7                  3.6                    3.6
# 13                     3.5                  3.3                    3.4
# 14                     4.8                  4.2                    4.4
# 15
# 16
#
#                Unnamed: 11             Unnamed: 12        K Kvinder  \
# 0   082 Region Midtjylland  081 Region Nordjylland  000 Hele landet
# 1                      2.2                     3.3              4.4
# 2                      1.8                     2.7              2.9
# 3                      5.1                     6.5              4.1
# 4                      6.3                     7.7              5.1
# 5                      5.3                     6.6              5.7
# 6                      5.1                     6.1                6
# 7                      4.9                     5.6              5.8
# 8                        4                     5.2              5.2
# 9                      3.5                     4.8              4.8
# 10                     3.2                     4.2              4.4
# 11                     3.4                     4.6              4.4
# 12                     3.2                     4.2              4.1
# 13                     3.1                     3.8              3.9
# 14                       4                     4.9              4.7
# 15
# 16
#
#                Unnamed: 14          Unnamed: 15            Unnamed: 16  \
# 0   084 Region Hovedstaden  085 Region Sjælland  083 Region Syddanmark
# 1                      4.4                  4.3                    4.2
# 2                      3.1                  2.8                    2.7
# 3                      4.1                  3.9                      4
# 4                      5.2                  5.1                    5.2
# 5                      5.7                  5.9                    5.7
# 6                        6                  6.2                    6.2
# 7                      5.8                  5.9                      6
# 8                      5.3                  5.1                    5.2
# 9                      4.8                  4.7                    4.7
# 10                     4.4                  4.3                    4.3
# 11                     4.4                  4.4                    4.3
# 12                     4.1                  4.1                    3.9
# 13                     3.9                  3.7                    3.8
# 14                     4.9                  4.3                    4.5
# 15
# 16
#
#                Unnamed: 17             Unnamed: 18
# 0   082 Region Midtjylland  081 Region Nordjylland
# 1                      3.7                     5.9
# 2                      2.4                     3.7
# 3                      3.8                     4.8
# 4                      4.8                     5.5
# 5                      5.3                     5.9
# 6                      5.6                       6
# 7                      5.3                     5.7
# 8                      4.7                     5.4
# 9                      4.3                     5.3
# 10                       4                     4.9
# 11                       4                     4.8
# 12                     3.8                     4.5
# 13                     3.7                     4.3
# 14                     4.5                     5.1
# 15
# 16

# %%
#Renaming columns
unemp = unemp.rename(columns={"Unnamed: 0": "Years","TOT I alt":"Entire country (All)","Unnamed: 2":"Capital region (All)","Unnamed: 3":"Zealand (All)","Unnamed: 4":"South Denmark (All)","Unnamed: 5":"Mid Jutland (All)","Unnamed: 6":"Northern Jutland (A)", "M Mænd":"Entire Country (M)", "Unnamed: 8":"Capital region (M)","Unnamed: 9":"Zealand (M)","Unnamed: 10":"South Denmark (M)","Unnamed: 11":"Mid Jutland (M)","Unnamed: 12":"Northern Jutland (M)","K Kvinder":"Entire country (W)","Unnamed: 14":"Capital region (W)","Unnamed: 15":"Zealand (W)","Unnamed: 16":"South Denmark (W)","Unnamed: 17":"Mid Jutland (W)","Unnamed: 18":"Northern Jutland (W)"})
unemp
# Out:
#    Years Entire country (All) Capital region (All) Zealand (All)  \
# 0   2007                  3.6                    4           3.5
# 1   2008                  2.6                    3           2.6
# 2   2009                  4.8                  4.7           4.7
# 3   2010                  6.1                    6           6.2
# 4   2011                  5.9                    6           6.2
# 5   2012                    6                  6.2           6.2
# 6   2013                  5.8                    6           5.8
# 7   2014                    5                  5.3             5
# 8   2015                  4.5                  4.7           4.6
# 9   2016                  4.1                  4.3           4.1
# 10  2017                  4.2                  4.2           4.2
# 11  2018                  3.8                  3.9           3.8
# 12  2019                  3.7                  3.7           3.5
# 13  2020                  4.6                  4.8           4.3
#
#    South Denmark (All) Mid Jutland (All) Northern Jutland (A)  \
# 0                  3.3               2.9                  4.5
# 1                  2.4               2.1                  3.2
# 2                  4.8               4.5                  5.7
# 3                  6.2               5.6                  6.6
# 4                  6.1               5.3                  6.3
# 5                  6.3               5.3                  6.1
# 6                  5.9               5.1                  5.6
# 7                  4.9               4.3                  5.3
# 8                  4.6               3.9                    5
# 9                  4.2               3.6                  4.5
# 10                 4.2               3.7                  4.7
# 11                 3.7               3.5                  4.3
# 12                 3.6               3.4                  4.1
# 13                 4.5               4.2                    5
#
#    Entire Country (M) Capital region (M) Zealand (M) South Denmark (M)  \
# 0                 2.9                3.7         2.7               2.6
# 1                 2.4                  3         2.4               2.1
# 2                 5.5                5.3         5.4               5.4
# 3                 6.9                6.7         7.2               7.1
# 4                 6.2                6.4         6.4               6.4
# 5                 6.1                6.3         6.2               6.4
# 6                 5.7                6.2         5.8               5.8
# 7                 4.8                5.3         4.9               4.7
# 8                 4.4                4.6         4.4               4.4
# 9                 3.9                4.1         3.9                 4
# 10                  4                4.1           4               4.1
# 11                3.6                3.7         3.6               3.6
# 12                3.4                3.5         3.3               3.4
# 13                4.5                4.8         4.2               4.4
#
#    Mid Jutland (M) Northern Jutland (M) Entire country (W) Capital region (W)  \
# 0              2.2                  3.3                4.4                4.4
# 1              1.8                  2.7                2.9                3.1
# 2              5.1                  6.5                4.1                4.1
# 3              6.3                  7.7                5.1                5.2
# 4              5.3                  6.6                5.7                5.7
# 5              5.1                  6.1                  6                  6
# 6              4.9                  5.6                5.8                5.8
# 7                4                  5.2                5.2                5.3
# 8              3.5                  4.8                4.8                4.8
# 9              3.2                  4.2                4.4                4.4
# 10             3.4                  4.6                4.4                4.4
# 11             3.2                  4.2                4.1                4.1
# 12             3.1                  3.8                3.9                3.9
# 13               4                  4.9                4.7                4.9
#
#    Zealand (W) South Denmark (W) Mid Jutland (W) Northern Jutland (W)
# 0          4.3               4.2             3.7                  5.9
# 1          2.8               2.7             2.4                  3.7
# 2          3.9                 4             3.8                  4.8
# 3          5.1               5.2             4.8                  5.5
# 4          5.9               5.7             5.3                  5.9
# 5          6.2               6.2             5.6                    6
# 6          5.9                 6             5.3                  5.7
# 7          5.1               5.2             4.7                  5.4
# 8          4.7               4.7             4.3                  5.3
# 9          4.3               4.3               4                  4.9
# 10         4.4               4.3               4                  4.8
# 11         4.1               3.9             3.8                  4.5
# 12         3.7               3.8             3.7                  4.3
# 13         4.3               4.5             4.5                  5.1

# %%
#dropping row 0
unemp=unemp.drop(0).head(16)
unemp
# Out:
#    Years Entire country (All) Capital region (All) Zealand (All)  \
# 1   2008                  2.6                    3           2.6
# 2   2009                  4.8                  4.7           4.7
# 3   2010                  6.1                    6           6.2
# 4   2011                  5.9                    6           6.2
# 5   2012                    6                  6.2           6.2
# 6   2013                  5.8                    6           5.8
# 7   2014                    5                  5.3             5
# 8   2015                  4.5                  4.7           4.6
# 9   2016                  4.1                  4.3           4.1
# 10  2017                  4.2                  4.2           4.2
# 11  2018                  3.8                  3.9           3.8
# 12  2019                  3.7                  3.7           3.5
# 13  2020                  4.6                  4.8           4.3
#
#    South Denmark (All) Mid Jutland (All) Northern Jutland (A)  \
# 1                  2.4               2.1                  3.2
# 2                  4.8               4.5                  5.7
# 3                  6.2               5.6                  6.6
# 4                  6.1               5.3                  6.3
# 5                  6.3               5.3                  6.1
# 6                  5.9               5.1                  5.6
# 7                  4.9               4.3                  5.3
# 8                  4.6               3.9                    5
# 9                  4.2               3.6                  4.5
# 10                 4.2               3.7                  4.7
# 11                 3.7               3.5                  4.3
# 12                 3.6               3.4                  4.1
# 13                 4.5               4.2                    5
#
#    Entire Country (M) Capital region (M) Zealand (M) South Denmark (M)  \
# 1                 2.4                  3         2.4               2.1
# 2                 5.5                5.3         5.4               5.4
# 3                 6.9                6.7         7.2               7.1
# 4                 6.2                6.4         6.4               6.4
# 5                 6.1                6.3         6.2               6.4
# 6                 5.7                6.2         5.8               5.8
# 7                 4.8                5.3         4.9               4.7
# 8                 4.4                4.6         4.4               4.4
# 9                 3.9                4.1         3.9                 4
# 10                  4                4.1           4               4.1
# 11                3.6                3.7         3.6               3.6
# 12                3.4                3.5         3.3               3.4
# 13                4.5                4.8         4.2               4.4
#
#    Mid Jutland (M) Northern Jutland (M) Entire country (W) Capital region (W)  \
# 1              1.8                  2.7                2.9                3.1
# 2              5.1                  6.5                4.1                4.1
# 3              6.3                  7.7                5.1                5.2
# 4              5.3                  6.6                5.7                5.7
# 5              5.1                  6.1                  6                  6
# 6              4.9                  5.6                5.8                5.8
# 7                4                  5.2                5.2                5.3
# 8              3.5                  4.8                4.8                4.8
# 9              3.2                  4.2                4.4                4.4
# 10             3.4                  4.6                4.4                4.4
# 11             3.2                  4.2                4.1                4.1
# 12             3.1                  3.8                3.9                3.9
# 13               4                  4.9                4.7                4.9
#
#    Zealand (W) South Denmark (W) Mid Jutland (W) Northern Jutland (W)
# 1          2.8               2.7             2.4                  3.7
# 2          3.9                 4             3.8                  4.8
# 3          5.1               5.2             4.8                  5.5
# 4          5.9               5.7             5.3                  5.9
# 5          6.2               6.2             5.6                    6
# 6          5.9                 6             5.3                  5.7
# 7          5.1               5.2             4.7                  5.4
# 8          4.7               4.7             4.3                  5.3
# 9          4.3               4.3               4                  4.9
# 10         4.4               4.3               4                  4.8
# 11         4.1               3.9             3.8                  4.5
# 12         3.7               3.8             3.7                  4.3
# 13         4.3               4.5             4.5                  5.1

# %%
#Dropping last two rows
unemp.drop(unemp.tail(2).index,inplace=True)
unemp
# Out:
#    Years Entire country (All) Capital region (All) Zealand (All)  \
# 1   2008                  2.6                    3           2.6
# 2   2009                  4.8                  4.7           4.7
# 3   2010                  6.1                    6           6.2
# 4   2011                  5.9                    6           6.2
# 5   2012                    6                  6.2           6.2
# 6   2013                  5.8                    6           5.8
# 7   2014                    5                  5.3             5
# 8   2015                  4.5                  4.7           4.6
# 9   2016                  4.1                  4.3           4.1
# 10  2017                  4.2                  4.2           4.2
# 11  2018                  3.8                  3.9           3.8
#
#    South Denmark (All) Mid Jutland (All) Northern Jutland (A)  \
# 1                  2.4               2.1                  3.2
# 2                  4.8               4.5                  5.7
# 3                  6.2               5.6                  6.6
# 4                  6.1               5.3                  6.3
# 5                  6.3               5.3                  6.1
# 6                  5.9               5.1                  5.6
# 7                  4.9               4.3                  5.3
# 8                  4.6               3.9                    5
# 9                  4.2               3.6                  4.5
# 10                 4.2               3.7                  4.7
# 11                 3.7               3.5                  4.3
#
#    Entire Country (M) Capital region (M) Zealand (M) South Denmark (M)  \
# 1                 2.4                  3         2.4               2.1
# 2                 5.5                5.3         5.4               5.4
# 3                 6.9                6.7         7.2               7.1
# 4                 6.2                6.4         6.4               6.4
# 5                 6.1                6.3         6.2               6.4
# 6                 5.7                6.2         5.8               5.8
# 7                 4.8                5.3         4.9               4.7
# 8                 4.4                4.6         4.4               4.4
# 9                 3.9                4.1         3.9                 4
# 10                  4                4.1           4               4.1
# 11                3.6                3.7         3.6               3.6
#
#    Mid Jutland (M) Northern Jutland (M) Entire country (W) Capital region (W)  \
# 1              1.8                  2.7                2.9                3.1
# 2              5.1                  6.5                4.1                4.1
# 3              6.3                  7.7                5.1                5.2
# 4              5.3                  6.6                5.7                5.7
# 5              5.1                  6.1                  6                  6
# 6              4.9                  5.6                5.8                5.8
# 7                4                  5.2                5.2                5.3
# 8              3.5                  4.8                4.8                4.8
# 9              3.2                  4.2                4.4                4.4
# 10             3.4                  4.6                4.4                4.4
# 11             3.2                  4.2                4.1                4.1
#
#    Zealand (W) South Denmark (W) Mid Jutland (W) Northern Jutland (W)
# 1          2.8               2.7             2.4                  3.7
# 2          3.9                 4             3.8                  4.8
# 3          5.1               5.2             4.8                  5.5
# 4          5.9               5.7             5.3                  5.9
# 5          6.2               6.2             5.6                    6
# 6          5.9                 6             5.3                  5.7
# 7          5.1               5.2             4.7                  5.4
# 8          4.7               4.7             4.3                  5.3
# 9          4.3               4.3               4                  4.9
# 10         4.4               4.3               4                  4.8
# 11         4.1               3.9             3.8                  4.5

# %%
#reseting indices
unemp=unemp.reset_index(level=None, drop=True, inplace=False, col_level=0, col_fill='')
unemp
# Out:
#    Years Entire country (All) Capital region (All) Zealand (All)  \
# 0   2008                  2.6                    3           2.6
# 1   2009                  4.8                  4.7           4.7
# 2   2010                  6.1                    6           6.2
# 3   2011                  5.9                    6           6.2
# 4   2012                    6                  6.2           6.2
# 5   2013                  5.8                    6           5.8
# 6   2014                    5                  5.3             5
# 7   2015                  4.5                  4.7           4.6
# 8   2016                  4.1                  4.3           4.1
# 9   2017                  4.2                  4.2           4.2
# 10  2018                  3.8                  3.9           3.8
#
#    South Denmark (All) Mid Jutland (All) Northern Jutland (A)  \
# 0                  2.4               2.1                  3.2
# 1                  4.8               4.5                  5.7
# 2                  6.2               5.6                  6.6
# 3                  6.1               5.3                  6.3
# 4                  6.3               5.3                  6.1
# 5                  5.9               5.1                  5.6
# 6                  4.9               4.3                  5.3
# 7                  4.6               3.9                    5
# 8                  4.2               3.6                  4.5
# 9                  4.2               3.7                  4.7
# 10                 3.7               3.5                  4.3
#
#    Entire Country (M) Capital region (M) Zealand (M) South Denmark (M)  \
# 0                 2.4                  3         2.4               2.1
# 1                 5.5                5.3         5.4               5.4
# 2                 6.9                6.7         7.2               7.1
# 3                 6.2                6.4         6.4               6.4
# 4                 6.1                6.3         6.2               6.4
# 5                 5.7                6.2         5.8               5.8
# 6                 4.8                5.3         4.9               4.7
# 7                 4.4                4.6         4.4               4.4
# 8                 3.9                4.1         3.9                 4
# 9                   4                4.1           4               4.1
# 10                3.6                3.7         3.6               3.6
#
#    Mid Jutland (M) Northern Jutland (M) Entire country (W) Capital region (W)  \
# 0              1.8                  2.7                2.9                3.1
# 1              5.1                  6.5                4.1                4.1
# 2              6.3                  7.7                5.1                5.2
# 3              5.3                  6.6                5.7                5.7
# 4              5.1                  6.1                  6                  6
# 5              4.9                  5.6                5.8                5.8
# 6                4                  5.2                5.2                5.3
# 7              3.5                  4.8                4.8                4.8
# 8              3.2                  4.2                4.4                4.4
# 9              3.4                  4.6                4.4                4.4
# 10             3.2                  4.2                4.1                4.1
#
#    Zealand (W) South Denmark (W) Mid Jutland (W) Northern Jutland (W)
# 0          2.8               2.7             2.4                  3.7
# 1          3.9                 4             3.8                  4.8
# 2          5.1               5.2             4.8                  5.5
# 3          5.9               5.7             5.3                  5.9
# 4          6.2               6.2             5.6                    6
# 5          5.9                 6             5.3                  5.7
# 6          5.1               5.2             4.7                  5.4
# 7          4.7               4.7             4.3                  5.3
# 8          4.3               4.3               4                  4.9
# 9          4.4               4.3               4                  4.8
# 10         4.1               3.9             3.8                  4.5

# %%
####plotting unemployment (pct.) for women, men and in total

# %%
unemp[['Entire country (All)', 'Entire Country (M)', 'Entire country (W)']].plot(figsize=(12,6))
x = list(range(len(unemp["Years"])))
plt.ylabel('Unemployment in %')
plt.xlabel('Years 2007-2020')
plt.xticks(x, unemp["Years"])
plt.title('Unemployment in Denmark during 2007-2020')
plt.show()

# %% [markdown]
# We see that unemployment is generally higher for women than men during the period 2007-2008. An exception to this is during the financial crisis and the following years where unemployment for men was higher.

# %% [markdown]
# Looking at dataset for industries. We want to see if the difference in employment rates between women and men can be explained by them working in different industries.

# %%
industry
# Out:
#    Beskæftigede efter område, branche (DB07 10-grp.), tid og køn  \
# 0                               Enhed: 1.000 personer
# 1
# 2
# 3                                         Hele landet
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# 12
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0
# 1                                                         2008K1
# 2                                                           Mænd    Kvinder
# 3                     1 Landbrug, skovbrug og fiskeri         46         17
# 4   2 Industri, råstofindvinding og forsyningsvirk...        300        130
# 5                                    3 Bygge og anlæg        178         18
# 6                           4 Handel og transport mv.        373        257
# 7                      5 Information og kommunikation         74         35
# 8                        6 Finansiering og forsikring         42         41
# 9                       7 Ejendomshandel og udlejning         20         10
# 10                                  8 Erhvervsservice        107         98
# 11  9 Offentlig administration, undervisning og su...        255        602
# 12                 10 Kultur, fritid og anden service         49         73
#
#    Unnamed: 4 Unnamed: 5
# 0
# 1      2020K1
# 2        Mænd    Kvinder
# 3          40         12
# 4         242        100
# 5         149         14
# 6         386        265
# 7          87         29
# 8          44         37
# 9          24         14
# 10        159        127
# 11        260        636
# 12         58         75

# %%
#Renaming columns
industry = industry.rename(columns={"Unnamed: 1": "Branche","Unnamed: 2":"Mænd, 2008 K1","Unnamed: 3":"Kvinder, 2008 K1","Unnamed: 4":"Mænd, 2020 K2","Unnamed: 5":"Kvinder, 2020 K2"})
industry
# Out:
#    Beskæftigede efter område, branche (DB07 10-grp.), tid og køn  \
# 0                               Enhed: 1.000 personer
# 1
# 2
# 3                                         Hele landet
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# 12
#
#                                               Branche Mænd, 2008 K1  \
# 0
# 1                                                            2008K1
# 2                                                              Mænd
# 3                     1 Landbrug, skovbrug og fiskeri            46
# 4   2 Industri, råstofindvinding og forsyningsvirk...           300
# 5                                    3 Bygge og anlæg           178
# 6                           4 Handel og transport mv.           373
# 7                      5 Information og kommunikation            74
# 8                        6 Finansiering og forsikring            42
# 9                       7 Ejendomshandel og udlejning            20
# 10                                  8 Erhvervsservice           107
# 11  9 Offentlig administration, undervisning og su...           255
# 12                 10 Kultur, fritid og anden service            49
#
#    Kvinder, 2008 K1 Mænd, 2020 K2 Kvinder, 2020 K2
# 0
# 1                          2020K1
# 2           Kvinder          Mænd          Kvinder
# 3                17            40               12
# 4               130           242              100
# 5                18           149               14
# 6               257           386              265
# 7                35            87               29
# 8                41            44               37
# 9                10            24               14
# 10               98           159              127
# 11              602           260              636
# 12               73            58               75

# %%
#Dropping row 0, 1, 2
industry=industry.drop([0,1,2])
industry
# Out:
#    Beskæftigede efter område, branche (DB07 10-grp.), tid og køn  \
# 3                                         Hele landet
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# 12
#
#                                               Branche Mænd, 2008 K1  \
# 3                     1 Landbrug, skovbrug og fiskeri            46
# 4   2 Industri, råstofindvinding og forsyningsvirk...           300
# 5                                    3 Bygge og anlæg           178
# 6                           4 Handel og transport mv.           373
# 7                      5 Information og kommunikation            74
# 8                        6 Finansiering og forsikring            42
# 9                       7 Ejendomshandel og udlejning            20
# 10                                  8 Erhvervsservice           107
# 11  9 Offentlig administration, undervisning og su...           255
# 12                 10 Kultur, fritid og anden service            49
#
#    Kvinder, 2008 K1 Mænd, 2020 K2 Kvinder, 2020 K2
# 3                17            40               12
# 4               130           242              100
# 5                18           149               14
# 6               257           386              265
# 7                35            87               29
# 8                41            44               37
# 9                10            24               14
# 10               98           159              127
# 11              602           260              636
# 12               73            58               75

# %%
industry = industry.drop('Beskæftigede efter område, branche (DB07 10-grp.), tid og køn', 1)
# Out:
# /var/folders/r2/1xrlyn0x2239x5svpgbg13_m0000gn/T/ipykernel_60034/519451115.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   industry = industry.drop('Beskæftigede efter område, branche (DB07 10-grp.), tid og køn', 1)

# %%
industry
# Out:
#                                               Branche Mænd, 2008 K1  \
# 3                     1 Landbrug, skovbrug og fiskeri            46
# 4   2 Industri, råstofindvinding og forsyningsvirk...           300
# 5                                    3 Bygge og anlæg           178
# 6                           4 Handel og transport mv.           373
# 7                      5 Information og kommunikation            74
# 8                        6 Finansiering og forsikring            42
# 9                       7 Ejendomshandel og udlejning            20
# 10                                  8 Erhvervsservice           107
# 11  9 Offentlig administration, undervisning og su...           255
# 12                 10 Kultur, fritid og anden service            49
#
#    Kvinder, 2008 K1 Mænd, 2020 K2 Kvinder, 2020 K2
# 3                17            40               12
# 4               130           242              100
# 5                18           149               14
# 6               257           386              265
# 7                35            87               29
# 8                41            44               37
# 9                10            24               14
# 10               98           159              127
# 11              602           260              636
# 12               73            58               75

# %%
#group values
industry_grouped=industry.groupby('Branche').sum()
['Mænd, 2008 K1','Kvinder, 2008 K1']
industry_grouped
# Out:
#                                                     Mænd, 2008 K1  \
# Branche
# 1 Landbrug, skovbrug og fiskeri                                46
# 10 Kultur, fritid og anden service                             49
# 2 Industri, råstofindvinding og forsyningsvirks...            300
# 3 Bygge og anlæg                                              178
# 4 Handel og transport mv.                                     373
# 5 Information og kommunikation                                 74
# 6 Finansiering og forsikring                                   42
# 7 Ejendomshandel og udlejning                                  20
# 8 Erhvervsservice                                             107
# 9 Offentlig administration, undervisning og sun...            255
#
#                                                     Kvinder, 2008 K1  \
# Branche
# 1 Landbrug, skovbrug og fiskeri                                   17
# 10 Kultur, fritid og anden service                                73
# 2 Industri, råstofindvinding og forsyningsvirks...               130
# 3 Bygge og anlæg                                                  18
# 4 Handel og transport mv.                                        257
# 5 Information og kommunikation                                    35
# 6 Finansiering og forsikring                                      41
# 7 Ejendomshandel og udlejning                                     10
# 8 Erhvervsservice                                                 98
# 9 Offentlig administration, undervisning og sun...               602
#
#                                                     Mænd, 2020 K2  \
# Branche
# 1 Landbrug, skovbrug og fiskeri                                40
# 10 Kultur, fritid og anden service                             58
# 2 Industri, råstofindvinding og forsyningsvirks...            242
# 3 Bygge og anlæg                                              149
# 4 Handel og transport mv.                                     386
# 5 Information og kommunikation                                 87
# 6 Finansiering og forsikring                                   44
# 7 Ejendomshandel og udlejning                                  24
# 8 Erhvervsservice                                             159
# 9 Offentlig administration, undervisning og sun...            260
#
#                                                     Kvinder, 2020 K2
# Branche
# 1 Landbrug, skovbrug og fiskeri                                   12
# 10 Kultur, fritid og anden service                                75
# 2 Industri, råstofindvinding og forsyningsvirks...               100
# 3 Bygge og anlæg                                                  14
# 4 Handel og transport mv.                                        265
# 5 Information og kommunikation                                    29
# 6 Finansiering og forsikring                                      37
# 7 Ejendomshandel og udlejning                                     14
# 8 Erhvervsservice                                                127
# 9 Offentlig administration, undervisning og sun...               636

# %%
fields = ['Mænd, 2008 K1','Kvinder, 2008 K1']
colors = ['#1D2F6F', '#8390FA', '#6EAF46', '#FAC748']
labels = ['Mænd','Kvinder']
# figure and axis
fig, ax = plt.subplots(1, figsize=(12, 10))
# plot bars
left = len(industry_grouped) * [0]
for idx, name in enumerate(fields):
    plt.barh(industry_grouped.index, industry_grouped[name], left = left, color=colors[idx])
    left = left + industry_grouped[name]
# title, legend, labels
plt.title('Employment\n', loc='left')
plt.legend(labels, bbox_to_anchor=([0.55, 1, 0, 0]), ncol=4, frameon=False)
plt.xlabel('Number of workers (thousands)')
# remove spines
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
# adjust limits and draw grid lines
plt.ylim(-0.5, ax.get_yticks()[-1] + 0.5)
ax.set_axisbelow(True)
ax.xaxis.grid(color='gray', linestyle='dashed')
plt.show()

# %%
industry2
# Out:
#   Beskæftigede efter område, køn, tid og branche (DB07 10-grp.) Unnamed: 1  \
# 0                              Enhed: 1.000 personer
# 1
# 2                                        Hele landet                  Mænd
# 3
# 4                                                                  Kvinder
# 5
#
#   Unnamed: 2                       Unnamed: 3  \
# 0
# 1             1 Landbrug, skovbrug og fiskeri
# 2     2008K1                               46
# 3     2020K1                               40
# 4     2008K1                               17
# 5     2020K1                               12
#
#                                           Unnamed: 4        Unnamed: 5  \
# 0
# 1  2 Industri, råstofindvinding og forsyningsvirk...  3 Bygge og anlæg
# 2                                                300               178
# 3                                                242               149
# 4                                                130                18
# 5                                                100                14
#
#                   Unnamed: 6                      Unnamed: 7  \
# 0
# 1  4 Handel og transport mv.  5 Information og kommunikation
# 2                        373                              74
# 3                        386                              87
# 4                        257                              35
# 5                        265                              29
#
#                      Unnamed: 8                     Unnamed: 9  \
# 0
# 1  6 Finansiering og forsikring  7 Ejendomshandel og udlejning
# 2                            42                             20
# 3                            44                             24
# 4                            41                             10
# 5                            37                             14
#
#          Unnamed: 10                                        Unnamed: 11  \
# 0
# 1  8 Erhvervsservice  9 Offentlig administration, undervisning og su...
# 2                107                                                255
# 3                159                                                260
# 4                 98                                                602
# 5                127                                                636
#
#                           Unnamed: 12
# 0
# 1  10 Kultur, fritid og anden service
# 2                                  49
# 3                                  58
# 4                                  73
# 5                                  75

# %%
#Renaming columns
industry2 = industry2.rename(columns={"Unnamed: 1": "Køn","Unnamed: 2":"År","Unnamed: 3":"Landbrug, skovbrug og fiskeri","Unnamed: 4":"Industri, råstofindvinding og forsyningsvirksomhed", "Unnamed: 5":"Industri, råstofindvinding og forsyningsvirksomhed","Unnamed: 6":"Bygge og anlæg, 2008 K1","Unnamed: 7":"Bygge og anlæg, 2020 K1", "Unnamed: 8":"Handel og transport mv., 2018 K1", "Unnamed: 9":"Handel og transport mv., 2020 K1","Unnamed: 10":"Erhvervsservice., 2018 K1","Unnamed: 11":"Erhvervsservice., 2018 K1"})

# %%
#renaming columns
industries = industries.rename(columns={"Beskæftigede efter branche (DB07 10-grp.), tid, køn og område": "Industries","Unnamed: 1":"Years","Unnamed: 2":"Entire country (All)","Unnamed: 3":"Capital region (All)","Unnamed: 4":"Zealand (All)","Unnamed: 5":"South Denmark (All)","Unnamed: 6":"Mid Jutland (All)", "Unnamed: 7":"Northern Jutland (M)", "Unnamed: 8":"Entire country (M)","Unnamed: 9":"Capital region (M)","Unnamed: 10":"Zealand (M)","Unnamed: 11":"South Denmark (M)","Unnamed: 12":"Mid Jutland (M)","Unnamed: 13":"Northern Jutland (M)","Unnamed: 14":"Entire country (W)","Unnamed: 15":"Capital region (W)","Unnamed: 16":"Zealand (W)","Unnamed: 17":"South Denmark (W)","Unnamed: 18":"Mid Jutland (W)", "Unnamed: 19":"Northern Jutland (W)", })
industries
# Out:
#                                            Industries   Years  \
# 0                               Enhed: 1.000 personer
# 1
# 2
# 3                                   TOT Erhverv i alt  2008K1
# 4                                                      2020K1
# 5                     1 Landbrug, skovbrug og fiskeri  2008K1
# 6                                                      2020K1
# 7   2 Industri, råstofindvinding og forsyningsvirk...  2008K1
# 8                                                      2020K1
# 9                                    3 Bygge og anlæg  2008K1
# 10                                                     2020K1
# 11                          4 Handel og transport mv.  2008K1
# 12                                                     2020K1
# 13                     5 Information og kommunikation  2008K1
# 14                                                     2020K1
# 15                       6 Finansiering og forsikring  2008K1
# 16                                                     2020K1
# 17                      7 Ejendomshandel og udlejning  2008K1
# 18                                                     2020K1
# 19                                  8 Erhvervsservice  2008K1
# 20                                                     2020K1
# 21  9 Offentlig administration, undervisning og su...  2008K1
# 22                                                     2020K1
# 23                 10 Kultur, fritid og anden service  2008K1
# 24                                                     2020K1
#
#    Entire country (All) Capital region (All)    Zealand (All)  \
# 0
# 1                 I alt
# 2           Hele landet   Region Hovedstaden  Region Sjælland
# 3                  2726                  857              393
# 4                  2767                  936              366
# 5                    63                   ..                7
# 6                    52                   ..                6
# 7                   430                   85               51
# 8                   342                   77               41
# 9                   196                   47               38
# 10                  163                   39               30
# 11                  629                  188               95
# 12                  651                  211               88
# 13                  109                   58               14
# 14                  116                   69                9
# 15                   84                   40               13
# 16                   81                   42               11
# 17                   30                   12                4
# 18                   39                   15                6
# 19                  205                   91               28
# 20                  286                  126               33
# 21                  857                  277              128
# 22                  896                  298              127
# 23                  123                   54               14
# 24                  133                   56               15
#
#    South Denmark (All)   Mid Jutland (All) Northern Jutland (M)  \
# 0
# 1
# 2    Region Syddanmark  Region Midtjylland   Region Nordjylland
# 3                  576                 626                  275
# 4                  555                 638                  272
# 5                   23                  19                   11
# 6                   14                  20                   11
# 7                  118                 122                   53
# 8                   86                  98                   40
# 9                   46                  45                   20
# 10                  40                  35                   18
# 11                 136                 151                   60
# 12                 141                 152                   59
# 13                  11                  19                    7
# 14                  11                  21                    7
# 15                  10                  14                    6
# 16                  11                  13                    4
# 17                   5                   5                   ..
# 18                   6                   7                    5
# 19                  32                  40                   15
# 20                  46                  59                   22
# 21                 175                 187                   89
# 22                 175                 203                   94
# 23                  20                  24                   10
# 24                  24                  28                   11
#
#    Entire country (M)  Capital region (M)      Zealand (M)  South Denmark (M)  \
# 0
# 1                Mænd
# 2         Hele landet  Region Hovedstaden  Region Sjælland  Region Syddanmark
# 3                1444                 438              208                310
# 4                1453                 479              185                292
# 5                  46                  ..                5                 17
# 6                  40                  ..                4                  9
# 7                 300                  52               37                 83
# 8                 242                  43               28                 64
# 9                 178                  43               33                 41
# 10                149                  35               27                 37
# 11                373                 106               57                 82
# 12                386                 125               56                 84
# 13                 74                  38               11                  7
# 14                 87                  52                7                  7
# 15                 42                  21                6                  5
# 16                 44                  23                6                  6
# 17                 20                   8               ..                  4
# 18                 24                   9               ..                  4
# 19                107                  49               15                 17
# 20                159                  67               18                 25
# 21                255                  94               37                 48
# 22                260                 101               30                 44
# 23                 49                  24                4                  7
# 24                 58                  22                7                 10
#
#        Mid Jutland (M) Northern Jutland (M) Entire country (W)  \
# 0
# 1                                                      Kvinder
# 2   Region Midtjylland   Region Nordjylland        Hele landet
# 3                  336                  152               1282
# 4                  349                  148               1314
# 5                   14                    7                 17
# 6                   16                    9                 12
# 7                   89                   39                130
# 8                   73                   33                100
# 9                   42                   19                 18
# 10                  33                   17                 14
# 11                  91                   37                257
# 12                  88                   33                265
# 13                  13                    5                 35
# 14                  16                    5                 29
# 15                   7                   ..                 41
# 16                   7                   ..                 37
# 17                   4                   ..                 10
# 18                   5                    4                 14
# 19                  19                    7                 98
# 20                  35                   13                127
# 21                  46                   28                602
# 22                  61                   24                636
# 23                  10                    4                 73
# 24                  14                    5                 75
#
#     Capital region (W)      Zealand (W)  South Denmark (W)  \
# 0
# 1
# 2   Region Hovedstaden  Region Sjælland  Region Syddanmark
# 3                  419              185                266
# 4                  457              180                263
# 5                   ..               ..                  6
# 6                   ..               ..                  5
# 7                   34               13                 36
# 8                   34               13                 21
# 9                    5                5                  5
# 10                   4                4                  4
# 11                  82               38                 54
# 12                  86               32                 57
# 13                  19                4                  4
# 14                  16               ..                  4
# 15                  19                8                  5
# 16                  19                5                  5
# 17                   4               ..                 ..
# 18                   6               ..                 ..
# 19                  42               13                 15
# 20                  59               15                 21
# 21                 183               91                127
# 22                 197               97                130
# 23                  31               10                 12
# 24                  34                8                 14
#
#        Mid Jutland (W) Northern Jutland (W)
# 0
# 1
# 2   Region Midtjylland   Region Nordjylland
# 3                  290                  123
# 4                  290                  125
# 5                    5                   ..
# 6                    4                   ..
# 7                   33                   14
# 8                   25                    8
# 9                   ..                   ..
# 10                  ..                   ..
# 11                  59                   23
# 12                  64                   26
# 13                   6                   ..
# 14                   5                   ..
# 15                   7                   ..
# 16                   6                   ..
# 17                  ..                   ..
# 18                  ..                   ..
# 19                  21                    8
# 20                  24                    9
# 21                 141                   60
# 22                 142                   70
# 23                  14                    7
# 24                  14                    5

# %%
##dropping row 0, 1 and 2
industries=industries.drop([0,1,2]).head(24)

# %%
industries
# Out:
#                                            Industries   Years  \
# 3                                   TOT Erhverv i alt  2008K1
# 4                                                      2020K1
# 5                     1 Landbrug, skovbrug og fiskeri  2008K1
# 6                                                      2020K1
# 7   2 Industri, råstofindvinding og forsyningsvirk...  2008K1
# 8                                                      2020K1
# 9                                    3 Bygge og anlæg  2008K1
# 10                                                     2020K1
# 11                          4 Handel og transport mv.  2008K1
# 12                                                     2020K1
# 13                     5 Information og kommunikation  2008K1
# 14                                                     2020K1
# 15                       6 Finansiering og forsikring  2008K1
# 16                                                     2020K1
# 17                      7 Ejendomshandel og udlejning  2008K1
# 18                                                     2020K1
# 19                                  8 Erhvervsservice  2008K1
# 20                                                     2020K1
# 21  9 Offentlig administration, undervisning og su...  2008K1
# 22                                                     2020K1
# 23                 10 Kultur, fritid og anden service  2008K1
# 24                                                     2020K1
#
#    Entire country (All) Capital region (All) Zealand (All)  \
# 3                  2726                  857           393
# 4                  2767                  936           366
# 5                    63                   ..             7
# 6                    52                   ..             6
# 7                   430                   85            51
# 8                   342                   77            41
# 9                   196                   47            38
# 10                  163                   39            30
# 11                  629                  188            95
# 12                  651                  211            88
# 13                  109                   58            14
# 14                  116                   69             9
# 15                   84                   40            13
# 16                   81                   42            11
# 17                   30                   12             4
# 18                   39                   15             6
# 19                  205                   91            28
# 20                  286                  126            33
# 21                  857                  277           128
# 22                  896                  298           127
# 23                  123                   54            14
# 24                  133                   56            15
#
#    South Denmark (All) Mid Jutland (All) Northern Jutland (M)  \
# 3                  576               626                  275
# 4                  555               638                  272
# 5                   23                19                   11
# 6                   14                20                   11
# 7                  118               122                   53
# 8                   86                98                   40
# 9                   46                45                   20
# 10                  40                35                   18
# 11                 136               151                   60
# 12                 141               152                   59
# 13                  11                19                    7
# 14                  11                21                    7
# 15                  10                14                    6
# 16                  11                13                    4
# 17                   5                 5                   ..
# 18                   6                 7                    5
# 19                  32                40                   15
# 20                  46                59                   22
# 21                 175               187                   89
# 22                 175               203                   94
# 23                  20                24                   10
# 24                  24                28                   11
#
#    Entire country (M) Capital region (M) Zealand (M) South Denmark (M)  \
# 3                1444                438         208               310
# 4                1453                479         185               292
# 5                  46                 ..           5                17
# 6                  40                 ..           4                 9
# 7                 300                 52          37                83
# 8                 242                 43          28                64
# 9                 178                 43          33                41
# 10                149                 35          27                37
# 11                373                106          57                82
# 12                386                125          56                84
# 13                 74                 38          11                 7
# 14                 87                 52           7                 7
# 15                 42                 21           6                 5
# 16                 44                 23           6                 6
# 17                 20                  8          ..                 4
# 18                 24                  9          ..                 4
# 19                107                 49          15                17
# 20                159                 67          18                25
# 21                255                 94          37                48
# 22                260                101          30                44
# 23                 49                 24           4                 7
# 24                 58                 22           7                10
#
#    Mid Jutland (M) Northern Jutland (M) Entire country (W) Capital region (W)  \
# 3              336                  152               1282                419
# 4              349                  148               1314                457
# 5               14                    7                 17                 ..
# 6               16                    9                 12                 ..
# 7               89                   39                130                 34
# 8               73                   33                100                 34
# 9               42                   19                 18                  5
# 10              33                   17                 14                  4
# 11              91                   37                257                 82
# 12              88                   33                265                 86
# 13              13                    5                 35                 19
# 14              16                    5                 29                 16
# 15               7                   ..                 41                 19
# 16               7                   ..                 37                 19
# 17               4                   ..                 10                  4
# 18               5                    4                 14                  6
# 19              19                    7                 98                 42
# 20              35                   13                127                 59
# 21              46                   28                602                183
# 22              61                   24                636                197
# 23              10                    4                 73                 31
# 24              14                    5                 75                 34
#
#    Zealand (W) South Denmark (W) Mid Jutland (W) Northern Jutland (W)
# 3          185               266             290                  123
# 4          180               263             290                  125
# 5           ..                 6               5                   ..
# 6           ..                 5               4                   ..
# 7           13                36              33                   14
# 8           13                21              25                    8
# 9            5                 5              ..                   ..
# 10           4                 4              ..                   ..
# 11          38                54              59                   23
# 12          32                57              64                   26
# 13           4                 4               6                   ..
# 14          ..                 4               5                   ..
# 15           8                 5               7                   ..
# 16           5                 5               6                   ..
# 17          ..                ..              ..                   ..
# 18          ..                ..              ..                   ..
# 19          13                15              21                    8
# 20          15                21              24                    9
# 21          91               127             141                   60
# 22          97               130             142                   70
# 23          10                12              14                    7
# 24           8                14              14                    5

# %%
#reseting indices
industries=industries.reset_index(level=None, drop=True, inplace=False, col_level=0, col_fill='')

# %%
industries["Industry_year"]=industries["Industries"]+industries["Years"]

# %%
industries
# Out:
#                                            Industries   Years  \
# 0                                   TOT Erhverv i alt  2008K1
# 1                                                      2020K1
# 2                     1 Landbrug, skovbrug og fiskeri  2008K1
# 3                                                      2020K1
# 4   2 Industri, råstofindvinding og forsyningsvirk...  2008K1
# 5                                                      2020K1
# 6                                    3 Bygge og anlæg  2008K1
# 7                                                      2020K1
# 8                           4 Handel og transport mv.  2008K1
# 9                                                      2020K1
# 10                     5 Information og kommunikation  2008K1
# 11                                                     2020K1
# 12                       6 Finansiering og forsikring  2008K1
# 13                                                     2020K1
# 14                      7 Ejendomshandel og udlejning  2008K1
# 15                                                     2020K1
# 16                                  8 Erhvervsservice  2008K1
# 17                                                     2020K1
# 18  9 Offentlig administration, undervisning og su...  2008K1
# 19                                                     2020K1
# 20                 10 Kultur, fritid og anden service  2008K1
# 21                                                     2020K1
#
#    Entire country (All) Capital region (All) Zealand (All)  \
# 0                  2726                  857           393
# 1                  2767                  936           366
# 2                    63                   ..             7
# 3                    52                   ..             6
# 4                   430                   85            51
# 5                   342                   77            41
# 6                   196                   47            38
# 7                   163                   39            30
# 8                   629                  188            95
# 9                   651                  211            88
# 10                  109                   58            14
# 11                  116                   69             9
# 12                   84                   40            13
# 13                   81                   42            11
# 14                   30                   12             4
# 15                   39                   15             6
# 16                  205                   91            28
# 17                  286                  126            33
# 18                  857                  277           128
# 19                  896                  298           127
# 20                  123                   54            14
# 21                  133                   56            15
#
#    South Denmark (All) Mid Jutland (All) Northern Jutland (M)  \
# 0                  576               626                  275
# 1                  555               638                  272
# 2                   23                19                   11
# 3                   14                20                   11
# 4                  118               122                   53
# 5                   86                98                   40
# 6                   46                45                   20
# 7                   40                35                   18
# 8                  136               151                   60
# 9                  141               152                   59
# 10                  11                19                    7
# 11                  11                21                    7
# 12                  10                14                    6
# 13                  11                13                    4
# 14                   5                 5                   ..
# 15                   6                 7                    5
# 16                  32                40                   15
# 17                  46                59                   22
# 18                 175               187                   89
# 19                 175               203                   94
# 20                  20                24                   10
# 21                  24                28                   11
#
#    Entire country (M) Capital region (M)  ... South Denmark (M)  \
# 0                1444                438  ...               310
# 1                1453                479  ...               292
# 2                  46                 ..  ...                17
# 3                  40                 ..  ...                 9
# 4                 300                 52  ...                83
# 5                 242                 43  ...                64
# 6                 178                 43  ...                41
# 7                 149                 35  ...                37
# 8                 373                106  ...                82
# 9                 386                125  ...                84
# 10                 74                 38  ...                 7
# 11                 87                 52  ...                 7
# 12                 42                 21  ...                 5
# 13                 44                 23  ...                 6
# 14                 20                  8  ...                 4
# 15                 24                  9  ...                 4
# 16                107                 49  ...                17
# 17                159                 67  ...                25
# 18                255                 94  ...                48
# 19                260                101  ...                44
# 20                 49                 24  ...                 7
# 21                 58                 22  ...                10
#
#    Mid Jutland (M) Northern Jutland (M) Entire country (W) Capital region (W)  \
# 0              336                  152               1282                419
# 1              349                  148               1314                457
# 2               14                    7                 17                 ..
# 3               16                    9                 12                 ..
# 4               89                   39                130                 34
# 5               73                   33                100                 34
# 6               42                   19                 18                  5
# 7               33                   17                 14                  4
# 8               91                   37                257                 82
# 9               88                   33                265                 86
# 10              13                    5                 35                 19
# 11              16                    5                 29                 16
# 12               7                   ..                 41                 19
# 13               7                   ..                 37                 19
# 14               4                   ..                 10                  4
# 15               5                    4                 14                  6
# 16              19                    7                 98                 42
# 17              35                   13                127                 59
# 18              46                   28                602                183
# 19              61                   24                636                197
# 20              10                    4                 73                 31
# 21              14                    5                 75                 34
#
#    Zealand (W) South Denmark (W) Mid Jutland (W) Northern Jutland (W)  \
# 0          185               266             290                  123
# 1          180               263             290                  125
# 2           ..                 6               5                   ..
# 3           ..                 5               4                   ..
# 4           13                36              33                   14
# 5           13                21              25                    8
# 6            5                 5              ..                   ..
# 7            4                 4              ..                   ..
# 8           38                54              59                   23
# 9           32                57              64                   26
# 10           4                 4               6                   ..
# 11          ..                 4               5                   ..
# 12           8                 5               7                   ..
# 13           5                 5               6                   ..
# 14          ..                ..              ..                   ..
# 15          ..                ..              ..                   ..
# 16          13                15              21                    8
# 17          15                21              24                    9
# 18          91               127             141                   60
# 19          97               130             142                   70
# 20          10                12              14                    7
# 21           8                14              14                    5
#
#                                         Industry_year
# 0                             TOT Erhverv i alt2008K1
# 1                                              2020K1
# 2               1 Landbrug, skovbrug og fiskeri2008K1
# 3                                              2020K1
# 4   2 Industri, råstofindvinding og forsyningsvirk...
# 5                                              2020K1
# 6                              3 Bygge og anlæg2008K1
# 7                                              2020K1
# 8                     4 Handel og transport mv.2008K1
# 9                                              2020K1
# 10               5 Information og kommunikation2008K1
# 11                                             2020K1
# 12                 6 Finansiering og forsikring2008K1
# 13                                             2020K1
# 14                7 Ejendomshandel og udlejning2008K1
# 15                                             2020K1
# 16                            8 Erhvervsservice2008K1
# 17                                             2020K1
# 18  9 Offentlig administration, undervisning og su...
# 19                                             2020K1
# 20           10 Kultur, fritid og anden service2008K1
# 21                                             2020K1
#
# [22 rows x 21 columns]

# %%
industries_grouped=industries.groupby('Industries').sum()
[['Entire country (M)','Entire country (W)']]
industries_grouped
# Out:
# /var/folders/r2/1xrlyn0x2239x5svpgbg13_m0000gn/T/ipykernel_51770/1602746014.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.add is deprecated. In a future version, a TypeError will be raised. Before calling .add, select only columns which should be valid for the function.
#   industries_grouped=industries.groupby('Industries').sum()
#                                                                                                 Years  \
# Industries
#                                                     2020K12020K12020K12020K12020K12020K12020K12020...
# 1 Landbrug, skovbrug og fiskeri                                                                2008K1
# 10 Kultur, fritid og anden service                                                             2008K1
# 2 Industri, råstofindvinding og forsyningsvirks...                                             2008K1
# 3 Bygge og anlæg                                                                               2008K1
# 4 Handel og transport mv.                                                                      2008K1
# 5 Information og kommunikation                                                                 2008K1
# 6 Finansiering og forsikring                                                                   2008K1
# 7 Ejendomshandel og udlejning                                                                  2008K1
# 8 Erhvervsservice                                                                              2008K1
# 9 Offentlig administration, undervisning og sun...                                             2008K1
# TOT Erhverv i alt                                                                              2008K1
#
#                                                     Entire country (All)  \
# Industries
#                                                                     5526
# 1 Landbrug, skovbrug og fiskeri                                       63
# 10 Kultur, fritid og anden service                                   123
# 2 Industri, råstofindvinding og forsyningsvirks...                   430
# 3 Bygge og anlæg                                                     196
# 4 Handel og transport mv.                                            629
# 5 Information og kommunikation                                       109
# 6 Finansiering og forsikring                                          84
# 7 Ejendomshandel og udlejning                                         30
# 8 Erhvervsservice                                                    205
# 9 Offentlig administration, undervisning og sun...                   857
# TOT Erhverv i alt                                                   2726
#
#                                                     Zealand (All)  \
# Industries
#                                                               732
# 1 Landbrug, skovbrug og fiskeri                                 7
# 10 Kultur, fritid og anden service                             14
# 2 Industri, råstofindvinding og forsyningsvirks...             51
# 3 Bygge og anlæg                                               38
# 4 Handel og transport mv.                                      95
# 5 Information og kommunikation                                 14
# 6 Finansiering og forsikring                                   13
# 7 Ejendomshandel og udlejning                                   4
# 8 Erhvervsservice                                              28
# 9 Offentlig administration, undervisning og sun...            128
# TOT Erhverv i alt                                             393
#
#                                                     South Denmark (All)  \
# Industries
#                                                                    1109
# 1 Landbrug, skovbrug og fiskeri                                      23
# 10 Kultur, fritid og anden service                                   20
# 2 Industri, råstofindvinding og forsyningsvirks...                  118
# 3 Bygge og anlæg                                                     46
# 4 Handel og transport mv.                                           136
# 5 Information og kommunikation                                       11
# 6 Finansiering og forsikring                                         10
# 7 Ejendomshandel og udlejning                                         5
# 8 Erhvervsservice                                                    32
# 9 Offentlig administration, undervisning og sun...                  175
# TOT Erhverv i alt                                                   576
#
#                                                     Mid Jutland (All)  \
# Industries
#                                                                  1274
# 1 Landbrug, skovbrug og fiskeri                                    19
# 10 Kultur, fritid og anden service                                 24
# 2 Industri, råstofindvinding og forsyningsvirks...                122
# 3 Bygge og anlæg                                                   45
# 4 Handel og transport mv.                                         151
# 5 Information og kommunikation                                     19
# 6 Finansiering og forsikring                                       14
# 7 Ejendomshandel og udlejning                                       5
# 8 Erhvervsservice                                                  40
# 9 Offentlig administration, undervisning og sun...                187
# TOT Erhverv i alt                                                 626
#
#                                                    Northern Jutland (M)  \
# Industries
#                                                                     543
# 1 Landbrug, skovbrug og fiskeri                                      11
# 10 Kultur, fritid og anden service                                   10
# 2 Industri, råstofindvinding og forsyningsvirks...                   53
# 3 Bygge og anlæg                                                     20
# 4 Handel og transport mv.                                            60
# 5 Information og kommunikation                                        7
# 6 Finansiering og forsikring                                          6
# 7 Ejendomshandel og udlejning                                        ..
# 8 Erhvervsservice                                                    15
# 9 Offentlig administration, undervisning og sun...                   89
# TOT Erhverv i alt                                                   275
#
#                                                     Entire country (M)  \
# Industries
#                                                                   2902
# 1 Landbrug, skovbrug og fiskeri                                     46
# 10 Kultur, fritid og anden service                                  49
# 2 Industri, råstofindvinding og forsyningsvirks...                 300
# 3 Bygge og anlæg                                                   178
# 4 Handel og transport mv.                                          373
# 5 Information og kommunikation                                      74
# 6 Finansiering og forsikring                                        42
# 7 Ejendomshandel og udlejning                                       20
# 8 Erhvervsservice                                                  107
# 9 Offentlig administration, undervisning og sun...                 255
# TOT Erhverv i alt                                                 1444
#
#                                                     South Denmark (M)  \
# Industries
#                                                                   582
# 1 Landbrug, skovbrug og fiskeri                                    17
# 10 Kultur, fritid og anden service                                  7
# 2 Industri, råstofindvinding og forsyningsvirks...                 83
# 3 Bygge og anlæg                                                   41
# 4 Handel og transport mv.                                          82
# 5 Information og kommunikation                                      7
# 6 Finansiering og forsikring                                        5
# 7 Ejendomshandel og udlejning                                       4
# 8 Erhvervsservice                                                  17
# 9 Offentlig administration, undervisning og sun...                 48
# TOT Erhverv i alt                                                 310
#
#                                                     Mid Jutland (M)  \
# Industries
#                                                                 697
# 1 Landbrug, skovbrug og fiskeri                                  14
# 10 Kultur, fritid og anden service                               10
# 2 Industri, råstofindvinding og forsyningsvirks...               89
# 3 Bygge og anlæg                                                 42
# 4 Handel og transport mv.                                        91
# 5 Information og kommunikation                                   13
# 6 Finansiering og forsikring                                      7
# 7 Ejendomshandel og udlejning                                     4
# 8 Erhvervsservice                                                19
# 9 Offentlig administration, undervisning og sun...               46
# TOT Erhverv i alt                                               336
#
#                                                     Entire country (W)
# Industries
#                                                                   2623
# 1 Landbrug, skovbrug og fiskeri                                     17
# 10 Kultur, fritid og anden service                                  73
# 2 Industri, råstofindvinding og forsyningsvirks...                 130
# 3 Bygge og anlæg                                                    18
# 4 Handel og transport mv.                                          257
# 5 Information og kommunikation                                      35
# 6 Finansiering og forsikring                                        41
# 7 Ejendomshandel og udlejning                                       10
# 8 Erhvervsservice                                                   98
# 9 Offentlig administration, undervisning og sun...                 602
# TOT Erhverv i alt                                                 1282

# %% [markdown]
# ## Explore each data set

# %% [markdown]
# In order to be able to **explore the raw data**, you may provide **static** and **interactive plots** to show important developments

# %% [markdown]
# **Interactive plot** :

# %%
def plot_func():
    # Function that operates on data set
    pass

widgets.interact(plot_func, 
    # Let the widget interact with data through plot_func()    
);
# Out:
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %% [markdown]
# Explain what you see when moving elements of the interactive plot around.

# %% [markdown]
# # Merge data sets

# %% [markdown]
# Now you create combinations of your loaded data sets. Remember the illustration of a (inner) **merge**:

# %%
plt.figure(figsize=(15,7))
v = venn2(subsets = (4, 4, 10), set_labels = ('Data X', 'Data Y'))
v.get_label_by_id('100').set_text('dropped')
v.get_label_by_id('010').set_text('dropped' )
v.get_label_by_id('110').set_text('included')
plt.show()

# %% [markdown]
# Here we are dropping elements from both data set X and data set Y. A left join would keep all observations in data X intact and subset only from Y.
#
# Make sure that your resulting data sets have the correct number of rows and columns. That is, be clear about which observations are thrown away.
#
# **Note:** Don't make Venn diagrams in your own data project. It is just for exposition.

# %% [markdown]
# # Analysis

# %% [markdown]
# To get a quick overview of the data, we show some **summary statistics** on a meaningful aggregation.

# %% [markdown]
# MAKE FURTHER ANALYSIS. EXPLAIN THE CODE BRIEFLY AND SUMMARIZE THE RESULTS.

# %% [markdown]
# # Conclusion

# %% [markdown]
# ADD CONCISE CONLUSION.
